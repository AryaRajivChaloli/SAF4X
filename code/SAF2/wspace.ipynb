# %%
import pandas as pd
import string
from langdetect import detect  
from translate import translator
import re
import sys
import nltk
import emoji
import enchant
from translate import Translator
import validators
from textblob import TextBlob
from indic_transliteration import sanscript 
from indic_transliteration.sanscript import transliterate
#import language_check
#tool = language_check.LanguageTool('en-US')
from gingerit.gingerit import GingerIt
from googletrans import Translator
from vaderSentiment import SentimentIntensityAnalyzer

#from pycontractions import Contractions
#cont = Contractions('GoogleNews-vectors-negative300.bin')
#cont.load_models()

analyser = SentimentIntensityAnalyzer()
translator = Translator()
d = enchant.Dict("en_US")
parser = GingerIt()

# %%
df = pd.read_csv("merged_hin_en_sentiments.csv")
df.set_index("index", inplace = True)

dfen = pd.read_csv("merged_en_sentiments.csv", encoding='latin')
dfen.set_index("index", inplace = True)

# %%
cList = {"ain't": 'is not',
 "aren't": 'are not',
 "can't": 'cannot',
 "can't've": 'cannot have',
 "'cause": 'because',
 "could've": 'could have',
 "couldn't": 'could not',
 "couldn't've": 'could not have',
 "didn't": 'did not',
 "doesn't": 'does not',
 "don't": 'do not',
 "hadn't": 'had not',
 "hadn't've": 'had not have',
 "hasn't": 'has not',
 "haven't": 'have not',
 "he'd": 'he would',
 "he'd've": 'he would have',
 "he'll": 'he will',
 "he'll've": 'he will have',
 "he's": 'he is',
 "how'd": 'how would',
 "how'd'y": 'how do you',
 "how'll": 'how will',
 "how's": 'how is',
 "I'd": 'I would',
 "I'd've": 'I would have',
 "I'll": 'I will',
 "I'll've": 'I will have',
 "I'm": 'I am',
 "I've": 'I have',
 "isn't": 'is not',
 "it'd": 'it would',
 "it'd've": 'it would have',
 "it'll": 'it will',
 "it'll've": 'it will have',
 "it's": 'it is',
 "let's": 'let us',
 "ma'am": 'madam',
 "mayn't": 'may not',
 "might've": 'might have',
 "mightn't": 'might not',
 "mightn't've": 'might not have',
 "must've": 'must have',
 "mustn't": 'must not',
 "mustn't've": 'must not have',
 "needn't": 'need not',
 "needn't've": 'need not have',
 "o'clock": 'of the clock',
 "oughtn't": 'ought not',
 "oughtn't've": 'ought not have',
 "shan't": 'shall not',
 "sha'n't": 'shall not',
 "shan't've": 'shall not have',
 "she'd": 'she would',
 "she'd've": 'she would have',
 "she'll": 'she will',
 "she'll've": 'she will have',
 "she's": 'she is',
 "should've": 'should have',
 "shouldn't": 'should not',
 "shouldn't've": 'should not have',
 "so've": 'so have',
 "so's": 'so is',
 "that'd": 'that would',
 "that'd've": 'that would have',
 "that's": 'that is',
 "there'd": 'there would',
 "there'd've": 'there would have',
 "there's": 'there is',
 "they'd": 'they would',
 "they'd've": 'they would have',
 "they'll": 'they will',
 "they'll've": 'they will have',
 "they're": 'they are',
 "they've": 'they have',
 "to've": 'to have',
 "wasn't": 'was not',
 "we'd": 'we would',
 "we'd've": 'we would have',
 "we'll": 'we will',
 "we'll've": 'we will have',
 "we're": 'we are',
 "we've": 'we have',
 "weren't": 'were not',
 "what'll": 'what will',
 "what'll've": 'what will have',
 "what're": 'what are',
 "what's": 'what is',
 "what've": 'what have',
 "when's": 'when is',
 "when've": 'when have',
 "where'd": 'where did',
 "where's": 'where is',
 "where've": 'where have',
 "who'll": 'who will',
 "who'll've": 'who will have',
 "who's": 'who is',
 "who've": 'who have',
 "why's": 'why is',
 "why've": 'why have',
 "will've": 'will have',
 "won't": 'will not',
 "won't've": 'will not have',
 "would've": 'would have',
 "wouldn't": 'would not',
 "wouldn't've": 'would not have',
 "y'all": 'you all',
 "y'alls": 'you alls',
 "y'all'd": 'you all would',
 "y'all'd've": 'you all would have',
 "y'all're": 'you all are',
 "y'all've": 'you all have',
 "you'd": 'you would',
 "you'd've": 'you would have',
 "you'll": 'you will',
 "you'll've": 'you you will have',
 "you're": 'you are',
 "you've": 'you have',
 "amn't": 'am not',
 "daren't": 'dare not',
 "daresn't": 'dare not',
 "dasn't": 'dare not',
 "e'er": 'ever',
 'em': 'them',
 "everyone's": 'everyone is',
 'finna': 'fixing to',
 'gimme': 'give me',
 'gonna': 'going to',
 "gon't": 'go not',
 'gotta': 'got to',
 "he've": 'he have',
 "how're": 'how are',
 "I'm'a": 'I am about to',
 "I'm'o": 'I am going to',
 'kinda': 'kind of',
 "may've": 'may have',
 "ne'er": 'never',
 "o'": 'of',
 "o'er": 'over',
 "ol'": 'old',
 "shalln't": 'shall not',
 "somebody's": 'somebody is',
 "someone's": 'someone is',
 "something's": 'something is',
 "that'll": 'that will',
 "that're": 'that are',
 "there'll": 'there will',
 "there're": 'there are',
 "these're": 'these are',
 "this's": 'this is',
 "those're": 'those are',
 "'tis": 'it is',
 "'twas": 'it was',
 'wanna': 'want to',
 "what'd": 'what did',
 "where're": 'where are',
 "which's": 'which is',
 "who'd": 'who would',
 "who'd've": 'who would have',
 "who're": 'who are',
 "why'd": 'why did',
 "why're": 'why are',
 'Whatcha': 'What are you',
 'luv': 'love',
 'sux': 'sucks'}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expand_contractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)


def is_emoji(character):
    return character in emoji.UNICODE_EMOJI


def text_has_emoji(text):
    for character in text:
        if character in emoji.UNICODE_EMOJI:
            return True
    return False

def is_hyperlink(value):
    if(validators.domain(value) or validators.email(value) or validators.iban(value) or validators.ip_address.ipv4(value) or validators.ip_address.ipv6(value) or validators.mac_address(value) or validators.url(value, public=False) or validators.uuid(value)):
       return True
    else:
       return False

def all_special_chars(token):
    return all(i in string.punctuation for i in token)

def special_chars_and_nums(token):
    return bool(re.match('[0-9]', token)) or token[0]=='@' or token[0]=='#'

def trim_rep2(token):
    return re.sub("(.)\\1{2,}", "\\1", token)

def detect_lang(token):
    lang = TextBlob(token)  
    return lang.detect_language()

def part_of_en_dict(token):
    d_US = enchant.Dict("en_US")
    d_UK = enchant.Dict("en_UK")
    d_IN = enchant.Dict("en_IN")
    return (d_US.check(token) or d_UK.check(token) or d_IN.check(token))

def reverse_transliterate(token, src_lang):
    #considering only en-hi for now
    if(src_lang == 'en'):
        src = sanscript.ITRANS
    dst = sanscript.DEVANAGARI
    #add to check if word belongs to the dst lang dict, trial and error for all lang
    return transliterate(token, src, dst)

def translate_to_en(token):
    #translator= Translator(to_lang="en")
    #translation = translator.translate(token)
    #return translation
    translation = translator.translate(token, dest='en')
    return translation.text

def grammar_correction(text):
    return (parser.parse(text)['result']).split()

def sentiment_scores(sentence):  
    sid_obj = SentimentIntensityAnalyzer()  
    sentiment_dict = sid_obj.polarity_scores(sentence) 
    #print("Overall sentiment dictionary is : ", sentiment_dict) 
    #print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    #print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    #print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
    #print("Sentence Overall Rated As", end = " ") 
    print("Score: ",sentiment_dict['compound'])
    if sentiment_dict['compound'] >= 0.05 : 
        return 1 
    elif sentiment_dict['compound'] <= - 0.05 : 
        return -1 
    else : 
        return 0

# %%
link = 'dtgfjhkhttp://www.interiorsndecor.com/index.php/component/k2/item/46-studioÂ kn;kbhh'
#nltk.word_tokenize(link)
result = re.sub(r"http\S+", "", link)
result
# Out:
# 'dtgfjhk kn;kbhh'

# %%
#trial on examples
x_input = []
y_pred = []
y_actual = []
df_test = dfen.sample(frac=.0003)
for index, row in df_test.iterrows():
    x_input.append(row['Tweet'])
    y_actual.append(row['tag'])
print(len(x_input),len(y_actual))

# %%
df.iloc[0]['Tweet']

# %%
textneg = "simplistic , silly and tedious .", "it's so laddish and juvenile , only teenage boys could possibly find it funny .", "exploitative and largely devoid of the depth or sophistication that would make watching such a graphic treatment of the crimes bearable .", "@twitchhiker Watching u on This Morning, really amazing what u did", "Just getting ready to head off to work.  Had a great day yesterday and feel I've made a great decision.    Have a great day everyone!😀", "trying twitter for the first time"
texten = "Just getting ready to head off to work.  Had a great day yesterday and feel I have made a great decision.    Have a great day everyone!😀"
text = "Ishq di..... baajiyaan..... jeetiyaan.... naa haariyaan     Share the love !!!! #Ishqdibaajiyaan #Soorma https://t.co/o4LGNZYZvQ"

# %%
#Considering english text for now
num_proc = 1
cor_pred = 0
for idx in range(len(x_input)):
    text = x_input[idx]
    tokens = nltk.word_tokenize(expand_contractions(text))
    final_tokens = []
    final_text_tokens = []
    code_mixed = False
    for token in tokens:
        if(is_hyperlink(token)):
            continue
        elif(all_special_chars(token) or is_emoji(token) or special_chars_and_nums(token)):
            final_tokens.append(token)
        else:
            token = trim_rep2(token)
            #we identify the language the text is written in: Assuming all english text for now
            #src_lang = detect_lang(token)
            src_lang = 'en'
            #check if word is already a part of en dict
            #adding a placeholder in final to be replaced later once grammar is corrected
            final_tokens.append('word_placeholder')
            if(part_of_en_dict(token)):
                final_text_tokens.append(token)
            else:
                code_mixed = True
                rev_transliterated_word = reverse_transliterate(token.lower(), src_lang)
                en_translated_word = translate_to_en(rev_transliterated_word)
                if(token.isupper()):
                    en_translated_word = en_translated_word.upper()
                final_text_tokens.append(en_translated_word)
                
    if(code_mixed):
        grammar_corrected_text = grammar_correction(" ".join(final_text_tokens))
        code_mixed = False
    else:
        grammar_corrected_text = final_text_tokens

    text_index = 0
    for index in range(len(final_tokens)):
        if(final_tokens[index]=='word_placeholder'):
            final_tokens[index] = final_text_tokens[text_index]
            text_index+=1
    
    text_final = " ".join(final_tokens)
    y_out = sentiment_scores(text_final)
    y_pred.append(y_out)
    if(y_out == y_actual[idx]):
        cor_pred+=1
    print("Input:",num_proc,text)
    print("pred, actual",y_out,y_actual[idx]," -----Accuracy------: ",(cor_pred/num_proc)*100)
    print("#################################################################################")
    num_proc+=1

# %%
sentiment_scores("I'm so sorry!")

# %%
translate_to_en(reverse_transliterate("gajab",'en'))
# Out:
# 'Amazing'

# %%
analyzer = SentimentIntensityAnalyzer()
vs = analyzer.polarity_scores('ganda scheme')
print("{:-<65} {}".format(text, str(vs)))
# Out:
# Suprabhaata------------------------------------------------------ {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sentiment_scores("bois :-(")

# %%
nltk.word_tokenize("akcmm fkwf -1324fwelfw352")

# %%
def check_splcharacter(test):
    # Make own character set and pass 
    # this as argument in compile method
 
    string_check= re.compile('[@_!#$%^&*()<>?/\|}{~:]')
 
    # Pass the string in search 
    # method of regex object.
 
    if(string_check.search(test) == None):
        print("String does not contain Special Characters.") 
    else: 
        print("String contains Special Characters.")
        
check_splcharacter("This is good")

# %%
def check_splcharacter(token):
    string_check= re.compile('[@_!#$%^&*()<>?/\|}{~:,;!?]')
    if(string_check.search(token) == None):
        return False 
    return True

# %%
check_splcharacter(':')

# %%
$:
%)
%-)
&-:
&:
( '}{' )
(%
('-:
(':
((-:
(*
(-%
(-*
(-:
(-:0
(-:<
(-:o
(-:O
(-:{
(-:|>*
(-;
(-;|
(8
(:
(:0
(:<
(:o
(:O
(;
(;<
(=
(?:
(^:
(^;
(^;0
(^;o
(o:
)':
)-':
)-:
)-:<
)-:{
):
):<
):{
);<
*)
*-)
*-:
*-;
*:
*<|:-)
*\0/*
*^:
,-:
---'-;-{@
--<--<@
.-:
..###-:
..###:
/-:
/:
/:<
/=
/^:
/o:
0-8
0-|
0:)
0:-)
0:-3
0:03
0;^)
0_o
10q
1337
143
1432
14aa41
182
187
2g2b4g
2g2bt
2qt
3:(
3:)
3:-(
3:-)
4col
4q
5fs
8)
8-d
8-o
86
8d
:###..
:$
:&
:'(
:')
:'-(
:'-)
:(
:)
:*
:-###..
:-&
:-(
:-)
:-))
:-*
:-,
:-.
:-/
:-<
:-d
:-D
:-o
:-p
:-[
:-\
:-c
:-p
:-|
:-||
:-Þ
:/
:3
:<
:>
:?)
:?c
:@
:d
:D
:l
:o
:p
:s
:[
:\
:]
:^)
:^*
:^/
:^\
:^|
:c
:c)
:o)
:o/
:o\
:o|
:P
:{
:|
:}
:Þ
;)
;-)
;-*
;-]
;d
;D
;]
;^)
</3
<3
<:
<:-|
=)
=-3
=-d
=-D
=/
=3
=d
=D
=l
=\
=]
=p
=|
>-:
>.<
>:
>:(
>:)
>:-(
>:-)
>:/
>:o
>:p
>:[
>:\
>;(
>;)
>_>^
@:
@>-->--
@}-;-'---
{:
|-0
|-:
|-:>
|-o
|:
|;-)
|=
|^:
|o:
||-:
}:
}:(
}:)
}:-(
}:-)

# %%
f=open("smiley.txt")
lines = f.readlines()
sList = {}
for line in lines:
    s = re.sub('\n', '', line)
    sList[s] = str(hash(s))
sList

# %%
sList = {'$:': '-5775591050571123167',
 '%)': '6918099099175134859',
 '%-)': '-5616976888366766776',
 '&-:': '-6799196393729225453',
 '&:': '4116373961892278351',
 "( '}{' )": '-4661919095793812594',
 '(%': '-7390119029409238248',
 "('-:": '-1176533548974838378',
 "(':": '-288946784906448632',
 '((-:': '5214705680899336381',
 '(*': '-8314744249570983158',
 '(-%': '890309365337002399',
 '(-*': '-1202349411336727487',
 '(-:': '3876502721093805183',
 '(-:0': '2537770760831139748',
 '(-:<': '-6803905107300160412',
 '(-:o': '7753188501057435134',
 '(-:O': '-4113309204961422809',
 '(-:{': '-179064948072886579',
 '(-:|>*': '7470131352128016149',
 '(-;': '2001934297005394876',
 '(-;|': '-4915549373138970832',
 '(8': '7177768299249075293',
 '(:': '743378658368125008',
 '(:0': '-2404738321742009141',
 '(:<': '8105386229635653707',
 '(:o': '-7207811267207018196',
 '(:O': '-1345037979392832509',
 '(;': '-984917096941257299',
 '(;<': '4334284308147639580',
 '(=': '-8895380311539911283',
 '(?:': '8563628687875202630',
 '(^:': '-5970539796585527259',
 '(^;': '1544639179278464976',
 '(^;0': '-5020831216718506693',
 '(^;o': '4878797894016806333',
 '(o:': '-5046578097284323341',
 ")':": '3259454611516240607',
 ")-':": '4463211358794296053',
 ')-:': '-8467551937256838485',
 ')-:<': '7519616935924852927',
 ')-:{': '1461769094981333636',
 '):': '3868539617958424135',
 '):<': '6309589912682856755',
 '):{': '4160881591478896701',
 ');<': '2150232963623012524',
 '*)': '-6625799109352308366',
 '*-)': '5943503019321702588',
 '*-:': '-4396709499693561466',
 '*-;': '8061483508401435797',
 '*:': '4932169711202057416',
 '*<|:-)': '5578469792040447126',
 '*\\0/*': '-7762374940309818242',
 '*^:': '-8486947289559999349',
 ',-:': '-2414431753304963011',
 "---'-;-{@": '9139464429215720862',
 '--<--<@': '-442282838902803191',
 '.-:': '-3819484938818662957',
 '..###-:': '-7054833406089903803',
 '..###:': '-164368220946660016',
 '/-:': '2296408612211664989',
 '/:': '-2370535516510370902',
 '/:<': '-1055426437623452014',
 '/=': '-9032036766366041157',
 '/^:': '-2760262154251401995',
 '/o:': '-3659758593577707906',
 '0-8': '6370481810758012042',
 '0-|': '2864866436709815512',
 '0:)': '-5749734044486719391',
 '0:-)': '-8122874664896978176',
 '0:-3': '-7307737152335859663',
 '0:03': '5718210482787748185',
 '0;^)': '707375917137069913',
 '0_o': '9137142558475658391',
 '10q': '911821196125802077',
 '1337': '-8228148248459263961',
 '143': '-3370300939096716034',
 '1432': '-4086424340058825942',
 '14aa41': '-3368152922870306430',
 '182': '-8355775648240087015',
 '187': '6833745999811289812',
 '2g2b4g': '-792981096780077893',
 '2g2bt': '8973722032275636407',
 '2qt': '4910390702036743658',
 '3:(': '5704990547191607292',
 '3:)': '1561637202596835807',
 '3:-(': '-3757597297289720435',
 '3:-)': '6312347943596441462',
 '4col': '3532026496278617735',
 '4q': '3520019350717117890',
 '5fs': '4607955172331530262',
 '8)': '1228952373033925709',
 '8-d': '6878018975994420942',
 '8-o': '6722264324731716189',
 '86': '4472871918693317122',
 '8d': '-3582144242487917915',
 ':###..': '-3258211547321284327',
 ':$': '785461035427441037',
 ':&': '-8252856749755793599',
 ":'(": '1195693619053043090',
 ":')": '-3867482580544023249',
 ":'-(": '3669958747253255211',
 ":'-)": '-5423918124269863128',
 ':(': '-5015572601680138442',
 ':)': '-5154156394742669662',
 ':*': '2352227034547678489',
 ':-###..': '9099979459974978445',
 ':-&': '1314728562015409601',
 ':-(': '-2643108474488572821',
 ':-)': '3546769093473591944',
 ':-))': '-4148222505901266170',
 ':-*': '5847485535011068668',
 ':-,': '5283102988719842516',
 ':-.': '3698265510456848908',
 ':-/': '928052564705431898',
 ':-<': '1896169051684261535',
 ':-d': '-1328628065457714026',
 ':-D': '4458220967920300250',
 ':-o': '5232011470057997875',
 ':-p': '6080048536857773381',
 ':-[': '2230696222651950144',
 ':-\\': '-391338957837050003',
 ':-c': '2228390839508028989',
 ':-|': '-3300142479283151392',
 ':-||': '-8152464753758054711',
 ':-Þ': '-7392925058984880586',
 ':/': '4419234734275587838',
 ':3': '-7807054999825966466',
 ':<': '-290783845539888722',
 ':>': '6086885182644460729',
 ':?)': '-5085258050320294236',
 ':?c': '5431331458223242339',
 ':@': '2953410838462239016',
 ':d': '5878944731322267603',
 ':D': '6441043224705639021',
 ':l': '9091273075392143872',
 ':o': '-7532055946997953409',
 ':p': '-1227555050936368495',
 ':s': '-1706191351417667702',
 ':[': '-9038032266058812655',
 ':\\': '3415067713063829157',
 ':]': '-3177540824121549437',
 ':^)': '8086788012268895205',
 ':^*': '-8373842900252907451',
 ':^/': '-2707802922724011494',
 ':^\\': '-9096003570945093936',
 ':^|': '4675968365964735333',
 ':c': '-7111393752992873188',
 ':c)': '-2869411769725137547',
 ':o)': '1478169677255520964',
 ':o/': '5066344742833197114',
 ':o\\': '2134863562757591937',
 ':o|': '-4070819235094493796',
 ':P': '3054554715046417270',
 ':{': '-1738350623090655603',
 ':|': '-1268592028183582772',
 ':}': '3345854531291762065',
 ':Þ': '2306013208514129256',
 ';)': '5024948637342091238',
 ';-)': '7359771336454887525',
 ';-*': '5661525932809894246',
 ';-]': '-6839266093239107260',
 ';d': '-8579047182005159666',
 ';D': '-8821229646837710245',
 ';]': '-5431279597460191298',
 ';^)': '-8573657651877296097',
 '</3': '-1695628300519593630',
 '<3': '3670694106807187215',
 '<:': '7406830923496994498',
 '<:-|': '-4407807377909941716',
 '=)': '2156351037538165587',
 '=-3': '15037074669549593',
 '=-d': '-452252898576231598',
 '=-D': '-5199739144318196705',
 '=/': '4051125358175866930',
 '=3': '-5722786005478138616',
 '=d': '2120827046103283360',
 '=D': '-409714126044029482',
 '=l': '-4191663125014028307',
 '=\\': '-447161594047499972',
 '=]': '-4810922855043883379',
 '=p': '-7248734219003909704',
 '=|': '-5004960976239223956',
 '>-:': '-2124499330747793172',
 '>.<': '-5164781173411724327',
 '>:': '-1430329329873713382',
 '>:(': '8589561710604411407',
 '>:)': '2963460099213039186',
 '>:-(': '-2162053310512040456',
 '>:-)': '1842702239497519087',
 '>:/': '-2666476028271742017',
 '>:o': '1362731526029694998',
 '>:p': '-5269915790270677462',
 '>:[': '6994604641204369234',
 '>:\\': '-7263273829281072463',
 '>;(': '8799342644450022704',
 '>;)': '-5390095804834311458',
 '>_>^': '1685580499122859082',
 '@:': '5553058621153766046',
 '@>-->--': '8235868190629668239',
 "@}-;-'---": '1068371536570783805',
 '{:': '898482849747590558',
 '|-0': '-6301509953187676206',
 '|-:': '7859858874926894081',
 '|-:>': '7084907644758528616',
 '|-o': '-7162295624321718165',
 '|:': '-4745919248815579056',
 '|;-)': '-5378769776850077391',
 '|=': '555563825342298333',
 '|^:': '-1387411534306764247',
 '|o:': '548232956784944241',
 '||-:': '-7240277821133945000',
 '}:': '-3889853025577089463',
 '}:(': '-1377349367487740596',
 '}:)': '2540069643911903722',
 '}:-(': '5782399845606546582',
 '}:-)': '-5851770717823011663'}

srevList = {}
for k in sList:
    srevList[sList[k]] = k
srevList

# %%
s = "}:-(\n"
re.sub('\n', '', s)

# %%
srevList = {
 '-5775591050571123167': '$:',
 '6918099099175134859': '%)',
 '-5616976888366766776': '%-)',
 '-6799196393729225453': '&-:',
 '4116373961892278351': '&:',
 '-4661919095793812594': "( '}{' )",
 '-7390119029409238248': '(%',
 '-1176533548974838378': "('-:",
 '-288946784906448632': "(':",
 '5214705680899336381': '((-:',
 '-8314744249570983158': '(*',
 '890309365337002399': '(-%',
 '-1202349411336727487': '(-*',
 '3876502721093805183': '(-:',
 '2537770760831139748': '(-:0',
 '-6803905107300160412': '(-:<',
 '7753188501057435134': '(-:o',
 '-4113309204961422809': '(-:O',
 '-179064948072886579': '(-:{',
 '7470131352128016149': '(-:|>*',
 '2001934297005394876': '(-;',
 '-4915549373138970832': '(-;|',
 '7177768299249075293': '(8',
 '743378658368125008': '(:',
 '-2404738321742009141': '(:0',
 '8105386229635653707': '(:<',
 '-7207811267207018196': '(:o',
 '-1345037979392832509': '(:O',
 '-984917096941257299': '(;',
 '4334284308147639580': '(;<',
 '-8895380311539911283': '(=',
 '8563628687875202630': '(?:',
 '-5970539796585527259': '(^:',
 '1544639179278464976': '(^;',
 '-5020831216718506693': '(^;0',
 '4878797894016806333': '(^;o',
 '-5046578097284323341': '(o:',
 '3259454611516240607': ")':",
 '4463211358794296053': ")-':",
 '-8467551937256838485': ')-:',
 '7519616935924852927': ')-:<',
 '1461769094981333636': ')-:{',
 '3868539617958424135': '):',
 '6309589912682856755': '):<',
 '4160881591478896701': '):{',
 '2150232963623012524': ');<',
 '-6625799109352308366': '*)',
 '5943503019321702588': '*-)',
 '-4396709499693561466': '*-:',
 '8061483508401435797': '*-;',
 '4932169711202057416': '*:',
 '5578469792040447126': '*<|:-)',
 '-7762374940309818242': '*\\0/*',
 '-8486947289559999349': '*^:',
 '-2414431753304963011': ',-:',
 '9139464429215720862': "---'-;-{@",
 '-442282838902803191': '--<--<@',
 '-3819484938818662957': '.-:',
 '-7054833406089903803': '..###-:',
 '-164368220946660016': '..###:',
 '2296408612211664989': '/-:',
 '-2370535516510370902': '/:',
 '-1055426437623452014': '/:<',
 '-9032036766366041157': '/=',
 '-2760262154251401995': '/^:',
 '-3659758593577707906': '/o:',
 '6370481810758012042': '0-8',
 '2864866436709815512': '0-|',
 '-5749734044486719391': '0:)',
 '-8122874664896978176': '0:-)',
 '-7307737152335859663': '0:-3',
 '5718210482787748185': '0:03',
 '707375917137069913': '0;^)',
 '9137142558475658391': '0_o',
 '911821196125802077': '10q',
 '-8228148248459263961': '1337',
 '-3370300939096716034': '143',
 '-4086424340058825942': '1432',
 '-3368152922870306430': '14aa41',
 '-8355775648240087015': '182',
 '6833745999811289812': '187',
 '-792981096780077893': '2g2b4g',
 '8973722032275636407': '2g2bt',
 '4910390702036743658': '2qt',
 '5704990547191607292': '3:(',
 '1561637202596835807': '3:)',
 '-3757597297289720435': '3:-(',
 '6312347943596441462': '3:-)',
 '3532026496278617735': '4col',
 '3520019350717117890': '4q',
 '4607955172331530262': '5fs',
 '1228952373033925709': '8)',
 '6878018975994420942': '8-d',
 '6722264324731716189': '8-o',
 '4472871918693317122': '86',
 '-3582144242487917915': '8d',
 '-3258211547321284327': ':###..',
 '785461035427441037': ':$',
 '-8252856749755793599': ':&',
 '1195693619053043090': ":'(",
 '-3867482580544023249': ":')",
 '3669958747253255211': ":'-(",
 '-5423918124269863128': ":'-)",
 '-5015572601680138442': ':(',
 '-5154156394742669662': ':)',
 '2352227034547678489': ':*',
 '9099979459974978445': ':-###..',
 '1314728562015409601': ':-&',
 '-2643108474488572821': ':-(',
 '3546769093473591944': ':-)',
 '-4148222505901266170': ':-))',
 '5847485535011068668': ':-*',
 '5283102988719842516': ':-,',
 '3698265510456848908': ':-.',
 '928052564705431898': ':-/',
 '1896169051684261535': ':-<',
 '-1328628065457714026': ':-d',
 '4458220967920300250': ':-D',
 '5232011470057997875': ':-o',
 '6080048536857773381': ':-p',
 '2230696222651950144': ':-[',
 '-391338957837050003': ':-\\',
 '2228390839508028989': ':-c',
 '-3300142479283151392': ':-|',
 '-8152464753758054711': ':-||',
 '-7392925058984880586': ':-Þ',
 '4419234734275587838': ':/',
 '-7807054999825966466': ':3',
 '-290783845539888722': ':<',
 '6086885182644460729': ':>',
 '-5085258050320294236': ':?)',
 '5431331458223242339': ':?c',
 '2953410838462239016': ':@',
 '5878944731322267603': ':d',
 '6441043224705639021': ':D',
 '9091273075392143872': ':l',
 '-7532055946997953409': ':o',
 '-1227555050936368495': ':p',
 '-1706191351417667702': ':s',
 '-9038032266058812655': ':[',
 '3415067713063829157': ':\\',
 '-3177540824121549437': ':]',
 '8086788012268895205': ':^)',
 '-8373842900252907451': ':^*',
 '-2707802922724011494': ':^/',
 '-9096003570945093936': ':^\\',
 '4675968365964735333': ':^|',
 '-7111393752992873188': ':c',
 '-2869411769725137547': ':c)',
 '1478169677255520964': ':o)',
 '5066344742833197114': ':o/',
 '2134863562757591937': ':o\\',
 '-4070819235094493796': ':o|',
 '3054554715046417270': ':P',
 '-1738350623090655603': ':{',
 '-1268592028183582772': ':|',
 '3345854531291762065': ':}',
 '2306013208514129256': ':Þ',
 '5024948637342091238': ';)',
 '7359771336454887525': ';-)',
 '5661525932809894246': ';-*',
 '-6839266093239107260': ';-]',
 '-8579047182005159666': ';d',
 '-8821229646837710245': ';D',
 '-5431279597460191298': ';]',
 '-8573657651877296097': ';^)',
 '-1695628300519593630': '</3',
 '3670694106807187215': '<3',
 '7406830923496994498': '<:',
 '-4407807377909941716': '<:-|',
 '2156351037538165587': '=)',
 '15037074669549593': '=-3',
 '-452252898576231598': '=-d',
 '-5199739144318196705': '=-D',
 '4051125358175866930': '=/',
 '-5722786005478138616': '=3',
 '2120827046103283360': '=d',
 '-409714126044029482': '=D',
 '-4191663125014028307': '=l',
 '-447161594047499972': '=\\',
 '-4810922855043883379': '=]',
 '-7248734219003909704': '=p',
 '-5004960976239223956': '=|',
 '-2124499330747793172': '>-:',
 '-5164781173411724327': '>.<',
 '-1430329329873713382': '>:',
 '8589561710604411407': '>:(',
 '2963460099213039186': '>:)',
 '-2162053310512040456': '>:-(',
 '1842702239497519087': '>:-)',
 '-2666476028271742017': '>:/',
 '1362731526029694998': '>:o',
 '-5269915790270677462': '>:p',
 '6994604641204369234': '>:[',
 '-7263273829281072463': '>:\\',
 '8799342644450022704': '>;(',
 '-5390095804834311458': '>;)',
 '1685580499122859082': '>_>^',
 '5553058621153766046': '@:',
 '8235868190629668239': '@>-->--',
 '1068371536570783805': "@}-;-'---",
 '898482849747590558': '{:',
 '-6301509953187676206': '|-0',
 '7859858874926894081': '|-:',
 '7084907644758528616': '|-:>',
 '-7162295624321718165': '|-o',
 '-4745919248815579056': '|:',
 '-5378769776850077391': '|;-)',
 '555563825342298333': '|=',
 '-1387411534306764247': '|^:',
 '548232956784944241': '|o:',
 '-7240277821133945000': '||-:',
 '-3889853025577089463': '}:',
 '-1377349367487740596': '}:(',
 '2540069643911903722': '}:)',
 '5782399845606546582': '}:-(',
 '-5851770717823011663': '}:-)'}

# %%
("-5851770717823011663").isdigit()

# %%
def check_nums(token):
    return bool(re.match('^-?[0-9]\d*(\.\d+)?$', token))

# %%
#check_nums("-35267724sgfg5151")
# import the module 
from indic_transliteration import sanscript 
from indic_transliteration.sanscript import transliterate 
  
# the text to be transliterated 
text = "Suprabhaata"
  
# printing the transliterated text 
print(transliterate(text, sanscript.ITRANS, sanscript.KANNADA))
# Out:
# Sಉಪ್ರಭಾತ

# %%
from nltk.corpus import indian
len(nltk.corpus.indian.words('marathi.pos'))
# Out:
# 19066

# %%
from indicnlp.transliterate.unicode_transliterate import UnicodeIndicTransliterator
input_text='आज मौसम अच्छा है। सूरज उज्ज्वल है और बारिश के कोई संकेत नहीं हैं। इसलिए हम आज खेल सकते हैं!'

# Transliterate from Hindi to Telugu
print(UnicodeIndicTransliterator.transliterate(input_text,"hi","ka"))
# Out:
# आज मौसम अच्छा है। सूरज उज्ज्वल है और बारिश के कोई संकेत नहीं हैं। इसलिए हम आज खेल सकते हैं!

# %%
en_hi_transliterate = {}
f1 = open("crowd_transliterations.hi-en.txt", 'r', encoding='utf-8')
lines  = f1.readlines()
for line in lines:
    en,hi=line.split()
    en_hi_transliterate[en] = hi
len(en_hi_transliterate)

# %%
f2 = open("Hindi - Word Transliteration Pairs 1.txt", 'r', encoding='utf-8')
lines  = f2.readlines()
for line in lines:
    en,hi=line.split()
    en_hi_transliterate[en] = hi
len(en_hi_transliterate)

# %%
f3 = open("tran_dict.txt", 'w', encoding='utf-8')
f3.write(str(en_hi_transliterate))

# %%
df1 = pd.read_csv("sma_posts.csv")
df1.head

# %%
file = open("en-hi_transliterate.txt", 'r', encoding='utf-8')
lines = file.readlines()
len(lines)

# %%
#trial on examples
x_input = []
y_pred = []
y_actual = []
df1 = pd.read_csv("sma_posts.csv")
df1.set_index("Id", inplace = True)
for index, row in df1.iterrows():
    x_input.append(row['Text'])
    if((row['Sentiment']).lower()=='neutral'):
        y_actual.append(0)
    elif((row['Sentiment']).lower()=='negative'):
        y_actual.append(-1)
    elif((row['Sentiment']).lower()=='positive'):
        y_actual.append(1)
print(len(x_input),len(y_actual))

# %%
import pandas as pd
import string
from langdetect import detect  
from translate import translator
import re
import sys
import nltk
import emoji
import enchant
from translate import Translator
import validators
from textblob import TextBlob
from indic_transliteration import sanscript 
from indic_transliteration.sanscript import transliterate
from gingerit.gingerit import GingerIt
from googletrans import Translator

#from nltk.sentiment.vader import SentimentIntensityAnalyzer
from vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

translator = Translator()
d = enchant.Dict("en_US")
parser = GingerIt()

cList = {"ain't": 'is not',
 "aren't": 'are not',
 "can't": 'cannot',
 "can't've": 'cannot have',
 "'cause": 'because',
 "could've": 'could have',
 "couldn't": 'could not',
 "couldn't've": 'could not have',
 "didn't": 'did not',
 "doesn't": 'does not',
 "don't": 'do not',
 "hadn't": 'had not',
 "hadn't've": 'had not have',
 "hasn't": 'has not',
 "haven't": 'have not',
 "he'd": 'he would',
 "he'd've": 'he would have',
 "he'll": 'he will',
 "he'll've": 'he will have',
 "he's": 'he is',
 "how'd": 'how would',
 "how'd'y": 'how do you',
 "how'll": 'how will',
 "how's": 'how is',
 "I'd": 'I would',
 "I'd've": 'I would have',
 "I'll": 'I will',
 "I'll've": 'I will have',
 "I'm": 'I am',
 "I've": 'I have',
 "isn't": 'is not',
 "it'd": 'it would',
 "it'd've": 'it would have',
 "it'll": 'it will',
 "it'll've": 'it will have',
 "it's": 'it is',
 "let's": 'let us',
 "ma'am": 'madam',
 "mayn't": 'may not',
 "might've": 'might have',
 "mightn't": 'might not',
 "mightn't've": 'might not have',
 "must've": 'must have',
 "mustn't": 'must not',
 "mustn't've": 'must not have',
 "needn't": 'need not',
 "needn't've": 'need not have',
 "o'clock": 'of the clock',
 "oughtn't": 'ought not',
 "oughtn't've": 'ought not have',
 "shan't": 'shall not',
 "sha'n't": 'shall not',
 "shan't've": 'shall not have',
 "she'd": 'she would',
 "she'd've": 'she would have',
 "she'll": 'she will',
 "she'll've": 'she will have',
 "she's": 'she is',
 "should've": 'should have',
 "shouldn't": 'should not',
 "shouldn't've": 'should not have',
 "so've": 'so have',
 "so's": 'so is',
 "that'd": 'that would',
 "that'd've": 'that would have',
 "that's": 'that is',
 "there'd": 'there would',
 "there'd've": 'there would have',
 "there's": 'there is',
 "they'd": 'they would',
 "they'd've": 'they would have',
 "they'll": 'they will',
 "they'll've": 'they will have',
 "they're": 'they are',
 "they've": 'they have',
 "to've": 'to have',
 "wasn't": 'was not',
 "we'd": 'we would',
 "we'd've": 'we would have',
 "we'll": 'we will',
 "we'll've": 'we will have',
 "we're": 'we are',
 "we've": 'we have',
 "weren't": 'were not',
 "what'll": 'what will',
 "what'll've": 'what will have',
 "what're": 'what are',
 "what's": 'what is',
 "what've": 'what have',
 "when's": 'when is',
 "when've": 'when have',
 "where'd": 'where did',
 "where's": 'where is',
 "where've": 'where have',
 "who'll": 'who will',
 "who'll've": 'who will have',
 "who's": 'who is',
 "who've": 'who have',
 "why's": 'why is',
 "why've": 'why have',
 "will've": 'will have',
 "won't": 'will not',
 "won't've": 'will not have',
 "would've": 'would have',
 "wouldn't": 'would not',
 "wouldn't've": 'would not have',
 "y'all": 'you all',
 "y'alls": 'you alls',
 "y'all'd": 'you all would',
 "y'all'd've": 'you all would have',
 "y'all're": 'you all are',
 "y'all've": 'you all have',
 "you'd": 'you would',
 "you'd've": 'you would have',
 "you'll": 'you will',
 "you'll've": 'you you will have',
 "you're": 'you are',
 "you've": 'you have',
 "amn't": 'am not',
 "daren't": 'dare not',
 "daresn't": 'dare not',
 "dasn't": 'dare not',
 "e'er": 'ever',
 'em': 'them',
 "everyone's": 'everyone is',
 'finna': 'fixing to',
 'gimme': 'give me',
 'gonna': 'going to',
 "gon't": 'go not',
 'gotta': 'got to',
 "he've": 'he have',
 "how're": 'how are',
 "I'm'a": 'I am about to',
 "I'm'o": 'I am going to',
 'kinda': 'kind of',
 "may've": 'may have',
 "ne'er": 'never',
 "o'": 'of',
 "o'er": 'over',
 "ol'": 'old',
 "shalln't": 'shall not',
 "somebody's": 'somebody is',
 "someone's": 'someone is',
 "something's": 'something is',
 "that'll": 'that will',
 "that're": 'that are',
 "there'll": 'there will',
 "there're": 'there are',
 "these're": 'these are',
 "this's": 'this is',
 "those're": 'those are',
 "'tis": 'it is',
 "'twas": 'it was',
 'wanna': 'want to',
 "what'd": 'what did',
 "where're": 'where are',
 "which's": 'which is',
 "who'd": 'who would',
 "who'd've": 'who would have',
 "who're": 'who are',
 "why'd": 'why did',
 "why're": 'why are',
 'Whatcha': 'What are you',
 'luv': 'love',
 'sux': 'sucks'}

sList = {
 '$:': '-5775591050571123167',
 '%)': '6918099099175134859',
 '%-)': '-5616976888366766776',
 '&-:': '-6799196393729225453',
 '&:': '4116373961892278351',
 "( '}{' )": '-4661919095793812594',
 '(%': '-7390119029409238248',
 "('-:": '-1176533548974838378',
 "(':": '-288946784906448632',
 '((-:': '5214705680899336381',
 '(*': '-8314744249570983158',
 '(-%': '890309365337002399',
 '(-*': '-1202349411336727487',
 '(-:': '3876502721093805183',
 '(-:0': '2537770760831139748',
 '(-:<': '-6803905107300160412',
 '(-:o': '7753188501057435134',
 '(-:O': '-4113309204961422809',
 '(-:{': '-179064948072886579',
 '(-:|>*': '7470131352128016149',
 '(-;': '2001934297005394876',
 '(-;|': '-4915549373138970832',
 '(8': '7177768299249075293',
 '(:': '743378658368125008',
 '(:0': '-2404738321742009141',
 '(:<': '8105386229635653707',
 '(:o': '-7207811267207018196',
 '(:O': '-1345037979392832509',
 '(;': '-984917096941257299',
 '(;<': '4334284308147639580',
 '(=': '-8895380311539911283',
 '(?:': '8563628687875202630',
 '(^:': '-5970539796585527259',
 '(^;': '1544639179278464976',
 '(^;0': '-5020831216718506693',
 '(^;o': '4878797894016806333',
 '(o:': '-5046578097284323341',
 ")':": '3259454611516240607',
 ")-':": '4463211358794296053',
 ')-:': '-8467551937256838485',
 ')-:<': '7519616935924852927',
 ')-:{': '1461769094981333636',
 '):': '3868539617958424135',
 '):<': '6309589912682856755',
 '):{': '4160881591478896701',
 ');<': '2150232963623012524',
 '*)': '-6625799109352308366',
 '*-)': '5943503019321702588',
 '*-:': '-4396709499693561466',
 '*-;': '8061483508401435797',
 '*:': '4932169711202057416',
 '*<|:-)': '5578469792040447126',
 '*\\0/*': '-7762374940309818242',
 '*^:': '-8486947289559999349',
 ',-:': '-2414431753304963011',
 "---'-;-{@": '9139464429215720862',
 '--<--<@': '-442282838902803191',
 '.-:': '-3819484938818662957',
 '..###-:': '-7054833406089903803',
 '..###:': '-164368220946660016',
 '/-:': '2296408612211664989',
 '/:': '-2370535516510370902',
 '/:<': '-1055426437623452014',
 '/=': '-9032036766366041157',
 '/^:': '-2760262154251401995',
 '/o:': '-3659758593577707906',
 '0-8': '6370481810758012042',
 '0-|': '2864866436709815512',
 '0:)': '-5749734044486719391',
 '0:-)': '-8122874664896978176',
 '0:-3': '-7307737152335859663',
 '0:03': '5718210482787748185',
 '0;^)': '707375917137069913',
 '0_o': '9137142558475658391',
 '10q': '911821196125802077',
 '1337': '-8228148248459263961',
 '143': '-3370300939096716034',
 '1432': '-4086424340058825942',
 '14aa41': '-3368152922870306430',
 '182': '-8355775648240087015',
 '187': '6833745999811289812',
 '2g2b4g': '-792981096780077893',
 '2g2bt': '8973722032275636407',
 '2qt': '4910390702036743658',
 '3:(': '5704990547191607292',
 '3:)': '1561637202596835807',
 '3:-(': '-3757597297289720435',
 '3:-)': '6312347943596441462',
 '4col': '3532026496278617735',
 '4q': '3520019350717117890',
 '5fs': '4607955172331530262',
 '8)': '1228952373033925709',
 '8-d': '6878018975994420942',
 '8-o': '6722264324731716189',
 '86': '4472871918693317122',
 '8d': '-3582144242487917915',
 ':###..': '-3258211547321284327',
 ':$': '785461035427441037',
 ':&': '-8252856749755793599',
 ":'(": '1195693619053043090',
 ":')": '-3867482580544023249',
 ":'-(": '3669958747253255211',
 ":'-)": '-5423918124269863128',
 ':(': '-5015572601680138442',
 ':)': '-5154156394742669662',
 ':*': '2352227034547678489',
 ':-###..': '9099979459974978445',
 ':-&': '1314728562015409601',
 ':-(': '-2643108474488572821',
 ':-)': '3546769093473591944',
 ':-))': '-4148222505901266170',
 ':-*': '5847485535011068668',
 ':-,': '5283102988719842516',
 ':-.': '3698265510456848908',
 ':-/': '928052564705431898',
 ':-<': '1896169051684261535',
 ':-d': '-1328628065457714026',
 ':-D': '4458220967920300250',
 ':-o': '5232011470057997875',
 ':-p': '6080048536857773381',
 ':-[': '2230696222651950144',
 ':-\\': '-391338957837050003',
 ':-c': '2228390839508028989',
 ':-|': '-3300142479283151392',
 ':-||': '-8152464753758054711',
 ':-Þ': '-7392925058984880586',
 ':/': '4419234734275587838',
 ':3': '-7807054999825966466',
 ':<': '-290783845539888722',
 ':>': '6086885182644460729',
 ':?)': '-5085258050320294236',
 ':?c': '5431331458223242339',
 ':@': '2953410838462239016',
 ':d': '5878944731322267603',
 ':D': '6441043224705639021',
 ':l': '9091273075392143872',
 ':o': '-7532055946997953409',
 ':p': '-1227555050936368495',
 ':s': '-1706191351417667702',
 ':[': '-9038032266058812655',
 ':\\': '3415067713063829157',
 ':]': '-3177540824121549437',
 ':^)': '8086788012268895205',
 ':^*': '-8373842900252907451',
 ':^/': '-2707802922724011494',
 ':^\\': '-9096003570945093936',
 ':^|': '4675968365964735333',
 ':c': '-7111393752992873188',
 ':c)': '-2869411769725137547',
 ':o)': '1478169677255520964',
 ':o/': '5066344742833197114',
 ':o\\': '2134863562757591937',
 ':o|': '-4070819235094493796',
 ':P': '3054554715046417270',
 ':{': '-1738350623090655603',
 ':|': '-1268592028183582772',
 ':}': '3345854531291762065',
 ':Þ': '2306013208514129256',
 ';)': '5024948637342091238',
 ';-)': '7359771336454887525',
 ';-*': '5661525932809894246',
 ';-]': '-6839266093239107260',
 ';d': '-8579047182005159666',
 ';D': '-8821229646837710245',
 ';]': '-5431279597460191298',
 ';^)': '-8573657651877296097',
 '</3': '-1695628300519593630',
 '<3': '3670694106807187215',
 '<:': '7406830923496994498',
 '<:-|': '-4407807377909941716',
 '=)': '2156351037538165587',
 '=-3': '15037074669549593',
 '=-d': '-452252898576231598',
 '=-D': '-5199739144318196705',
 '=/': '4051125358175866930',
 '=3': '-5722786005478138616',
 '=d': '2120827046103283360',
 '=D': '-409714126044029482',
 '=l': '-4191663125014028307',
 '=\\': '-447161594047499972',
 '=]': '-4810922855043883379',
 '=p': '-7248734219003909704',
 '=|': '-5004960976239223956',
 '>-:': '-2124499330747793172',
 '>.<': '-5164781173411724327',
 '>:': '-1430329329873713382',
 '>:(': '8589561710604411407',
 '>:)': '2963460099213039186',
 '>:-(': '-2162053310512040456',
 '>:-)': '1842702239497519087',
 '>:/': '-2666476028271742017',
 '>:o': '1362731526029694998',
 '>:p': '-5269915790270677462',
 '>:[': '6994604641204369234',
 '>:\\': '-7263273829281072463',
 '>;(': '8799342644450022704',
 '>;)': '-5390095804834311458',
 '>_>^': '1685580499122859082',
 '@:': '5553058621153766046',
 '@>-->--': '8235868190629668239',
 "@}-;-'---": '1068371536570783805',
 '{:': '898482849747590558',
 '|-0': '-6301509953187676206',
 '|-:': '7859858874926894081',
 '|-:>': '7084907644758528616',
 '|-o': '-7162295624321718165',
 '|:': '-4745919248815579056',
 '|;-)': '-5378769776850077391',
 '|=': '555563825342298333',
 '|^:': '-1387411534306764247',
 '|o:': '548232956784944241',
 '||-:': '-7240277821133945000',
 '}:': '-3889853025577089463',
 '}:(': '-1377349367487740596',
 '}:)': '2540069643911903722',
 '}:-(': '5782399845606546582',
 '}:-)': '-5851770717823011663'
 }

tran_en_hi_file = open("en-hi_transliterate.txt", 'r', encoding='utf-8')
lines = tran_en_hi_file.readlines()
en_hi_transliterate = {}
for line in lines:
    en,hi = line.split()
    en_hi_transliterate[en.lower()] = hi

srevList = {}
for k in sList:
    srevList[sList[k]] = k

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expand_contractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)


def is_emoji(character):
    return character in emoji.UNICODE_EMOJI


def text_has_emoji(text):
    for character in text:
        if character in emoji.UNICODE_EMOJI:
            return True
    return False

def is_hyperlink(value):
    if(validators.domain(value) or validators.email(value) or validators.iban(value) or validators.ip_address.ipv4(value) 
        or validators.ip_address.ipv6(value) or validators.mac_address(value) or validators.url(value, public=False) or validators.uuid(value)):
       return True
    else:
       return False

def all_special_chars(token):
    return all(i in string.punctuation for i in token)

def check_nums(token):
    return bool(re.match('^-?[0-9]\d*(\.\d+)?$', token))

def check_splcharacter(token):
    string_check= re.compile('[@_!#$%^&*()<>?/\|}{~:,;!?]')
    if(string_check.search(token) == None):
        return False 
    return True

def trim_rep2(token):
    return re.sub("(.)\\1{2,}", "\\1", token)

def detect_lang(token):
    lang = TextBlob(token)  
    return lang.detect_language()

def part_of_en_dict(token):
    d_US = enchant.Dict("en_US")
    d_UK = enchant.Dict("en_UK")
    d_IN = enchant.Dict("en_IN")
    return (d_US.check(token) or d_UK.check(token) or d_IN.check(token))

def reverse_transliterate(token, src_lang):
    if(src_lang == 'en'):
        src = sanscript.ITRANS
    dst = sanscript.DEVANAGARI
    return transliterate(token, src, dst)

def translate_to_en(token):
    translation = translator.translate(token, dest='en')
    return translation.text

def grammar_correction(text):
    return (parser.parse(text)['result']).split()

def sentiment_scores(sentence): 
    sid_obj = SentimentIntensityAnalyzer() 
    sentiment_dict = sid_obj.polarity_scores(sentence) 
    #print("Overall sentiment dictionary is : ", sentiment_dict) 
    #print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    #print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    #print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
    #print("Sentence Overall Rated As", end = " ") 
    print("Compound ",sentiment_dict['compound'])
    if sentiment_dict['compound'] >= 0.05 : 
        return 1 
    elif sentiment_dict['compound'] <= - 0.05 : 
        return -1 
    else : 
        return 0

#text = input("Enter text here: ")

#replace smileys with hash val
for sm in sList:
    text = text.replace(sm, " "+sList[sm]+" ")

num_proc = 1
cor_pred = 0
for idx in range(len(x_input)):
    text = x_input[idx]
    tokens = nltk.word_tokenize(expand_contractions(text))
    final_tokens = []
    final_text_tokens = []
    code_mixed = False
    for token in tokens:
        if(is_hyperlink(token)):
            continue
        elif(is_emoji(token) or check_nums(token) or check_splcharacter(token) or all_special_chars(token)):
            final_tokens.append(token)
        elif(token.isalpha()):
            token = trim_rep2(token)
            src_lang = 'en'
            final_tokens.append('word_placeholder')
            if(part_of_en_dict(token)):
                final_text_tokens.append(token)
            else:
                code_mixed = True
                if(token.lower() in en_hi_transliterate):
                    rev_transliterated_word = en_hi_transliterate[token.lower()]
                else:
                    rev_transliterated_word = reverse_transliterate(token.lower(), src_lang)
                en_translated_word = translate_to_en(rev_transliterated_word)
                if(token.isupper()):
                    en_translated_word = en_translated_word.upper()
                final_text_tokens.append(en_translated_word)
        else:
            #assuming words written in other languages will be spelled correctly
            src_lang = detect_lang(token)
            final_tokens.append('word_placeholder')
            en_translated_word = translate_to_en(token)
            final_text_tokens.append(en_translated_word)

    if(code_mixed):
        grammar_corrected_text = grammar_correction(" ".join(final_text_tokens))
        code_mixed = False
    else:
        grammar_corrected_text = final_text_tokens

    text_index = 0
    for index in range(len(final_tokens)):
        if(final_tokens[index]=='word_placeholder'):
            final_tokens[index] = final_text_tokens[text_index]
            text_index+=1

    text_final = " ".join(final_tokens)
    for hsm in srevList:
        text_final = text_final.replace(hsm, srevList[hsm])

    y_out = sentiment_scores(text_final)
    y_pred.append(y_out)
    if(y_out == y_actual[idx]):
        cor_pred+=1
    print("Input:",num_proc,text)
    print("pred, actual",y_out,y_actual[idx]," -----Accuracy------: ",(cor_pred/num_proc)*100)
    print("#################################################################################")
    num_proc+=1

# %%
tran_en_hi_file = open("en-hi_transliterate.txt", 'r', encoding='utf-8')
lines = tran_en_hi_file.readlines()
en_hi_transliterate = {}
for line in lines:
    en,hi = line.split()
    en_hi_transliterate[en.lower()] = hi
en_hi_transliterate
# Out:
# {'hajagiree': '??????',
#  'chekaanv': '?????',
#  'spinagaarn': '??????????',
#  'medal': '????',
#  'chetthinaad': '?????????',
#  'hari': '???',
#  'bhoomi': '????',
#  'yaanhmsan': '??????',
#  'hanumaan': '??????',
#  'abhinetri': '?????????',
#  'to': '??',
#  'sikkim': '???????',
#  'abdus': '??????',
#  'salam': '????',
#  'alvar': '????',
#  'kapil': '????',
#  'dev': '???',
#  'baaflayer': '??????????',
#  'capilano': '????????',
#  'suspension': '????????',
#  'graham': '??????',
#  'stephenson': '????????',
#  'auckland': '??????',
#  'art': '????',
#  'museum': '????????',
#  'kamlesh': '?????',
#  'effi': '???',
#  'awards': '?????????',
#  'warren': '?????',
#  'visneski': '?????????',
#  'brus': '?????',
#  'aigar': '???',
#  'jaun': '????',
#  'miltan': '??????',
#  'ai': '??',
#  'yaad': '???',
#  'teri': '????',
#  'samad': '???',
#  'ernaa': '?????',
#  'shree': '????',
#  'ram': '??',
#  'bharat': '????',
#  'milap': '?????',
#  'roci': '??????',
#  'kedy': '????',
#  'madihah': '??????',
#  'aahlad': '??????',
#  'bornham': '????????',
#  'fort': '?????',
#  'erma': '?????',
#  'mera': '???',
#  'lalkar': '?????',
#  'apoorva': '??????',
#  'civilla': '??????',
#  'ranchi': '?????',
#  'kapila': '?????',
#  'modesti': '????????',
#  'elan': '????',
#  'vels': '?????',
#  'abhishok': '??????',
#  'bedard': '??????',
#  'jamana': '????',
#  'kya': '????',
#  'jaane': '????',
#  'aaditya': '??????',
#  'savitshri': '????????',
#  'abot': '????',
#  'india': '??????????',
#  'irfan': '?????',
#  'samedemose': '????????',
#  'chaarsee': '?????',
#  'mahafhooj': '??????',
#  'gardi': '??????',
#  'kofare': '?????',
#  'd': '?',
#  'perood': '?????',
#  'kovlin': '?????',
#  'crofd': '???????',
#  'tirupati': '???????',
#  'bhatti': '?????',
#  'gurdwara': '??????????',
#  'betma': '?????',
#  'sahib': '?????',
#  'zapata': '?????',
#  'bhanwar': '????',
#  'passenger': '????',
#  'gambler': '?????',
#  'adas': '???',
#  'ilenaabaad': '????????',
#  'varjeeniya': '?????????',
#  'reel': '???',
#  'intikaam': '???????',
#  'kee': '??',
#  'aag': '??',
#  'maijar': '????',
#  'arawalee': '??????',
#  'rod': '???',
#  'thayer': '?????',
#  'sentaems': '?????????',
#  'lut': '???',
#  'shyama': '??????',
#  'wilkin': '???????',
#  'darvin': '???????',
#  'yatim': '????',
#  'john': '???',
#  'pan': '??',
#  'gua': '???',
#  'sipinkuga': '????????',
#  'sekhva': '?????',
#  'aajam': '???',
#  'shakti': '?????',
#  'gordhan': '?????',
#  'chandresh': '???????',
#  'water': '????',
#  'polo': '????',
#  'aakhiri': '?????',
#  'adalat': '?????',
#  'university': '???????????',
#  'christopher': '??????????',
#  'reeve': '???',
#  'amriteshaya': '???????',
#  'vermillion': '?????????',
#  'bellerophon': '????????',
#  'nasa': '????',
#  'for': '???',
#  'exceptional': '??????????',
#  'off': '??',
#  'colorado': '????????',
#  'denvik': '??????',
#  'bhaskar': '??????',
#  'dugirala': '????????',
#  'pyaar': '????',
#  'ki': '??',
#  'baji': '????',
#  'kanak': '???',
#  'maulana': '??????',
#  'scientific': '?????????',
#  'achievement': '????????',
#  'abdul': '??????',
#  'tawwab': '??????',
#  'palm': '???',
#  'spring': '????????',
#  'henry': '????',
#  'williams': '????????',
#  'bodan': '????',
#  'kalam': '???',
#  'azaad': '????',
#  'patekar': '??????',
#  'rebaba': '??????',
#  'shark': '?????',
#  'naugty': '????',
#  'boy': '???',
#  'mesosphere': '??????????',
#  'dhanshyan': '???????',
#  'sun': '???',
#  'peolo': '?????',
#  'me': '??',
#  'sudesh': '?????',
#  'track': '?????',
#  'end': '????',
#  'field': '?????',
#  'ghamand': '????',
#  'juma': '????',
#  'centurion': '?????????',
#  'khalid': '?????',
#  'mashoodah': '????',
#  'anberdekr': '?????????',
#  'ghaare': '????',
#  'perin': '?????',
#  'over': '???',
#  'imposhsible': '?????',
#  'mevaaraam': '???????',
#  'divarath': '??????',
#  'guljar': '???????',
#  'andrew': '????????',
#  'flintoff': '????????',
#  'wilmet': '???????',
#  'blonde': '????',
#  'vanburn': '???????',
#  'holder': '??????',
#  'season': '???',
#  'treacherous': '?????',
#  'chaina': '????',
#  'national': '?????',
#  'rajendramohan': '????????????',
#  'sadanand': '??????',
#  'dholpur': '??????',
#  'nasrin': '?????',
#  'zamaana': '?????',
#  'order': '???',
#  'sikatuna': '????????',
#  'kaala': '????',
#  'dhandha': '????',
#  'petroleum': '??????????',
#  'barnet': '???????',
#  'vedgya': '??????',
#  'parwez': '?????',
#  'gohpur': '??????',
#  'chunnilaal': '?????????',
#  'nadere': '?????',
#  'ireland': '???????',
#  'bansuri': '??????',
#  'sewan': '????',
#  'gore': '????',
#  'log': '???',
#  'rock': '???',
#  'lake': '????',
#  'baspist': '????????',
#  'pakararima': '?????????',
#  'mahadevi': '???????',
#  'verma': '?????',
#  'jatan': '???',
#  'braveward': '?????????',
#  'mails': '??????',
#  'aenaadaayar': '???????',
#  'katak': '???',
#  'zyoorik': '???????',
#  'faainaanshiyal': '??????????',
#  'sarvisez': '????????',
#  'mishelin': '???????',
#  'varta': '??????',
#  'gullapoor': '????????',
#  'brita': '?????',
#  'gaaye': '????',
#  'vittal': '????????',
#  'empero': '??????',
#  'jaagran': '?????',
#  'samprprith': '????????',
#  'florus': '??????',
#  'julia': '??????',
#  'child': '??????',
#  'corporation': '??????????',
#  'bank': '????',
#  'dalel': '????',
#  'river': '????',
#  'phoenix': '???????',
#  'swanna': '???????',
#  'chandril': '???????',
#  'hisham': '?????',
#  'syed': '?????',
#  'kirmani': '???????',
#  'balawali': '???????',
#  'siddheshwari': '???????????',
#  'varship': '??????',
#  'sentar': '??????',
#  'kaiptan': '??????',
#  'bairee': '????',
#  'shikhkar': '????',
#  'par': '???',
#  'gurjeet': '??????',
#  'aelsaas': '??????',
#  'seviyar': '??????',
#  'baanchar': '????',
#  'memoriyal': '????????',
#  'praais': '??????',
#  'valt': '?????',
#  'dijani': '??????',
#  'kritendan': '?????????',
#  'kalevari': '???????',
#  'baiptist': '????????',
#  'beljiyam': '????????',
#  'intal': '????',
#  'bijnes': '??????',
#  'kash': '???',
#  'sautan': '????',
#  'beti': '????',
#  'steve': '?????',
#  'rikson': '??????',
#  'yashima': '?????',
#  'milicent': '????????',
#  'saya': '????',
#  'machines': '??????',
#  'mahageet': '??????',
#  'charles': '???????',
#  'kauvantri': '?????????',
#  'sheila': '????',
#  'khudra': '????',
#  'kasam': '???',
#  'anuva': '?????',
#  'makil': '????',
#  'liyouna': '??????',
#  'baintula': '???????',
#  'varnapura': '?????????',
#  'thnavant': '?????',
#  'iklawit': '??????',
#  'myritaim': '????????',
#  'merit': '?????',
#  'anhkom': '?????',
#  'harshele': '??????',
#  'gibs': '?????',
#  'banujaah': '??????',
#  'damount': '??????',
#  'basmaah': '??????',
#  'endi': '?????',
#  'paicroft': '??????????',
#  'gender': '?????',
#  'pinkwillow': '?????????',
#  'may': '??',
#  'santa': '?????',
#  'mariya': '??????',
#  'stevan': '??????',
#  'playvin': '???????',
#  'takaniya': '???????',
#  'talav': '????',
#  'abhijvala': '?????????',
#  'luckjambark': '???????????',
#  'zeeda': '????',
#  'yoonivarsiti': '???????????',
#  'kalej': '?????',
#  'landan': '????',
#  'gehamar': '?????',
#  'priyathaa': '???????',
#  'teleree': '??????',
#  'chchindavaadaa': '????????',
#  'jankshan': '??????',
#  'malik': '????',
#  'raiphelo': '??????',
#  'phoebe': '?????',
#  'cage': '??????',
#  'amer': '????',
#  'devgan': '?????',
#  'road': '???',
#  'mujahid': '???????',
#  'jamshed': '?????',
#  'suzuki': '??????',
#  'motor': '?????',
#  'broadwater': '?????????',
#  'bagri': '?????',
#  'sajanpure': '????????',
#  'niramay': '??????',
#  'hum': '???',
#  'tum': '??',
#  'aur': '??',
#  'wo': '??',
#  'amanat': '?????',
#  'ichhita': '???????',
#  'jaiki': '????',
#  'devdharkar': '???????',
#  'hasan': '???',
#  'shaik': '???',
#  'haimdres': '???????',
#  'agar': '???',
#  'na': '??',
#  'hote': '????',
#  'adhikar': '??????',
#  'vinodini': '????????',
#  'amlaai': '??????',
#  'debashish': '???????',
#  'kaushik': '?????',
#  'somanshu': '???????',
#  'karsan': '??????',
#  'ghavri': '?????',
#  'opto': '?????',
#  'circuits': '????????',
#  'noma': '????',
#  'aacharyasuta': '??????????',
#  'suraj': '????',
#  'gyanda': '???????',
#  'roshan': '????',
#  'jurangpathi': '????????',
#  'jaisi': '????',
#  'james': '?????',
#  'aage': '???',
#  'badho': '???',
#  'abhayprad': '???????',
#  'prize': '??????',
#  'literature': '????????',
#  'waqt': '????',
#  'deewar': '?????',
#  'ahmed': '????',
#  'kamaal': '????',
#  'jawaharlal': '????????',
#  'nehru': '?????',
#  'tirupatisaram': '???????????',
#  'asif': '????',
#  'mahmood': '?????',
#  'triptaa': '??????',
#  'raveesh': '????',
#  'berish': '?????',
#  'dam': '??',
#  'kashef': '????',
#  'saiful': '?????',
#  'islam': '??????',
#  'biswesvraya': '????????????',
#  'preet': '?????',
#  'not': '???',
#  'the': '????',
#  'reet': '???',
#  'supreme': '???????',
#  'petro': '??????',
#  'pearsa': '???????',
#  'film': '?????',
#  'he': '??',
#  'manthan': '????',
#  'akram': '????',
#  'sawal': '????',
#  'ayyappan': '????????',
#  'baseera': '????',
#  'vinugopal': '?????????',
#  'raav': '???',
#  'nimish': '?????',
#  'aap': '??',
#  'marji': '?????',
#  'kvenacho': '????????',
#  'lokesh': '?????',
#  'aabhir': '????',
#  'nippon': '???????',
#  'mining': '???????',
#  'holdings': '??????????',
#  'havange': '??????',
#  'priks': '???????',
#  'medisis': '???????',
#  'lusander': '?????????',
#  'formidable': '??????????',
#  'jodi': '????',
#  'kanyalal': '??????????',
#  'kin': '???',
#  'salaam': '????',
#  'kelkar': '?????',
#  'chelsiyaa': '????????',
#  'zizzee': '????',
#  'jeeval': '????',
#  'vaasanti': '??????',
#  'dharam': '???',
#  'veer': '???',
#  'galenis': '???????',
#  'paanl': '???',
#  'varlis': '???????',
#  'greeh': '?????',
#  'hastreet': '?????????',
#  'forte': '?????',
#  'worth': '????',
#  'teja': '????',
#  'tejal': '????',
#  'khidaike': '?????',
#  'kunti': '?????',
#  'keena': '????',
#  'yasmin': '???????',
#  'madhuchanda': '????????',
#  'javait': '????',
#  'dayjan': '?????',
#  'javan': '????',
#  'kioto': '??????',
#  'moskva': '????????',
#  'anjane': '??????',
#  'mohammad': '???????',
#  'madani': '?????',
#  'miya': '????',
#  'asrafi': '?????',
#  'ashapurna': '?????????',
#  'devi': '????',
#  'sarey': '????',
#  'luck': '??????',
#  'violence': '???????',
#  'trigental': '??????????',
#  'georgia': '????????',
#  'osmund': '?????',
#  'nabraska': '??????????',
#  'bhadran': '?????',
#  'shoab': '????',
#  'kaviraj': '??????',
#  'hainis': '??????',
#  'bhilwara': '???????',
#  'hujes': '???????',
#  'hare': '???',
#  'kaanch': '????',
#  'chudiyna': '???????',
#  'jaindra': '???????',
#  'jeki': '????',
#  'baba': '??',
#  'bule': '????',
#  'shah': '???',
#  'shaikh': '???',
#  'chilli': '??????',
#  'divine': '??????',
#  'nagar': '????',
#  'done': '??',
#  'shiv': '???',
#  'raatri': '??????',
#  'nagma': '????',
#  'deep': '???',
#  'daasgupta': '?????????',
#  'banani': '?????',
#  'sudarshna': '????????',
#  'tayibaaha': '????????',
#  'banaahi': '?????',
#  'bhagavaanpura': '?????????',
#  'anokha': '?????',
#  'rishta': '??????',
#  'scent': '????',
#  'meri': '????',
#  'naseer': '????',
#  'duff': '??',
#  'ka': '??',
#  'phaamarn': '??????',
#  'gurudwara': '??????????',
#  'tibbi': '??????',
#  'saahib': '?????',
#  'tarkkas': '????',
#  'mout': '???',
#  'kaa': '??',
#  'tufaan': '?????',
#  'harraarey': '?????',
#  'jeraald': '???????',
#  'goarade': '?????',
#  'lele': '????',
#  'darbar': '?????',
#  'mutti': '??????',
#  'nafarat': '????',
#  'aanhdhi': '????',
#  'gaay': '???',
#  'dog': '???',
#  'sibojiryam': '??????????',
#  'lalitkishore': '?????????',
#  'sugtiy': '??????',
#  'sabak': '???',
#  'hatyare': '???????',
#  'khemchand': '??????',
#  'naalko': '??????',
#  'bayar': '????',
#  'badavi': '?????',
#  'devgam': '?????',
#  'waltars': '????????',
#  'afsana': '?????',
#  'slasen': '???????',
#  'gas': '???',
#  'shungare': '???????',
#  'kaheesha': '?????',
#  'smith': '?????',
#  'shekel': '?????',
#  'josaf': '????',
#  'stelin': '???????',
#  'hinge': '?????',
#  'bankiyaw': '????????',
#  'liyonardo': '??????????',
#  'kepriyo': '????????',
#  'garnet': '??????',
#  'krugar': '??????',
#  'war': '??',
#  'chittar': '??????',
#  'indian': '???????',
#  'omar': '???',
#  'kheyyam': '??????',
#  'players': '????????',
#  'formalisis': '????????????',
#  'limited': '???????',
#  'pawaskar': '??????',
#  'faninath': '??????',
#  'edlin': '?????',
#  'sant': '????',
#  'xyanershwar': '??????????',
#  'raghvendra': '?????????',
#  'natu': '????',
#  'cheboob': '?????',
#  'babu': '????',
#  'memon': '????',
#  'express': '?????????',
#  'itochu': '?????',
#  'atroli': '???????',
#  'sapna': '????',
#  'taisir': '?????',
#  'murre': '??????',
#  'gudwin': '??????',
#  'dark': '????',
#  'street': '???????',
#  'sikkrapts': '???????????',
#  'aakash': '????',
#  'frank': '??????',
#  'raj': '??',
#  'tilak': '????',
#  'laakirn': '???????',
#  'riyaan': '?????',
#  'vanmata': '??????',
#  'international': '?????????',
#  'paper': '????',
#  'jet': '???',
#  'airways': '??????',
#  'anadyant': '????????',
#  'gujjar': '??????',
#  'banba': '?????',
#  'actress': '????????',
#  'kyun': '?????',
#  'bani': '????',
#  'hasina': '?????',
#  'maan': '???',
#  'iravti': '??????',
#  'makisma': '???????',
#  'sumitra': '????????????',
#  'vishya': '?????',
#  'hind': '?????',
#  'edakad': '????????',
#  'herve': '?????',
#  'derrick': '?????',
#  'more': '????',
#  'jaegi': '?????',
#  'amarp': '????',
#  'lawarris': '???????',
#  'fakhrh': '????',
#  'roj': '???',
#  'kennedy': '??????',
#  'arsikeri': '????????',
#  'junction': '??????',
#  'detective': '?????????',
#  'janu': '????',
#  'riverside': '????????',
#  'marsabit': '????????',
#  'and': '??',
#  'reserve': '??????',
#  'jagmohan': '??????',
#  'sanjeevan': '??????',
#  'mahindra': '????????',
#  'yujin': '?????',
#  'mangalore': '???????',
#  'chemicals': '????????',
#  'mishol': '?????',
#  'london': '????',
#  'dublin': '???????',
#  'writers': '???????',
#  'do': '??',
#  'aanhgee': '?????',
#  'enig': '????',
#  'bhell': '???',
#  'myginsheyam': '??????????',
#  'ranghaava': '??????',
#  'looyisa': '?????',
#  'kep': '???',
#  'code': '???',
#  'faded': '?????',
#  'neenth': '????',
#  'hamare': '????',
#  'khyalab': '?????',
#  'tomhara': '????????',
#  'neris': '?????',
#  'townsand': '????????',
#  'bawli': '?????',
#  'chunauti': '??????',
#  'ghatprabha': '????????',
#  'brook': '?????',
#  'chandiya': '??????',
#  'ginis': '??????',
#  'world': '??????',
#  'offf': '??',
#  'records': '?????????',
#  'muquabla': '???????',
#  'abhimand': '???????',
#  'linel': '??????',
#  'wanker': '????',
#  'shubhang': '??????',
#  'delta': '??????',
#  'ear': '???',
#  'lains': '??????',
#  'thomson': '?????',
#  'jack': '???',
#  'nicholson': '???????',
#  'mohsin': '??????',
#  'khan': '???',
#  'vidya': '??????',
#  'vardhak': '?????',
#  'sang': '????',
#  'high': '???',
#  'school': '?????',
#  'bangalore': '???????',
#  'jurat': '??????',
#  'haikla': '??????',
#  'ajay': '???',
#  'krushna': '??????',
#  'grant': '??????',
#  'breadburn': '?????????',
#  'saaransh': '??????',
#  'elita': '?????',
#  'rahima': '????',
#  'ajmat': '?????',
#  'yomhas': '????',
#  'army': '?????',
#  'public': '?????',
#  'new': '???',
#  'delhi': '??????',
#  'garhi': '?????',
#  'maanikpur': '????????',
#  'adam': '???',
#  'kaavli': '?????',
#  'price': '??????',
#  'glora': '??????',
#  'benito': '??????',
#  'musolini': '????????',
#  'jaysudha': '??????',
#  'federal': '??????',
#  'templo': '???????',
#  'day': '??',
#  'pen': '???',
#  'royal': '????',
#  'academy': '??????',
#  'of': '??',
#  'arts': '??????',
#  'julinka': '????????',
#  'bats': '?????',
#  'anikuttan': '??????????',
#  'reservoir': '????????',
#  'david': '?????',
#  'albanjaa': '???????',
#  'a': '?',
#  'builinggul': '?????????',
#  'siberut': '???????',
#  'hamdi': '?????',
#  'jeend': '????',
#  'dream': '?????',
#  'girl': '????',
#  'biwi': '????',
#  'lloyd': '?????????',
#  'blhind': '?????',
#  'suwo': '????',
#  'aftab': '?????',
#  'radha': '???',
#  'sita': '????',
#  'khubgawkar': '????????',
#  'prabhas': '??????',
#  'great': '?????',
#  'sandy': '?????',
#  'nalayak': '??????',
#  'richard': '??????',
#  'bartan': '?????',
#  'newbery': '????????',
#  'honour': '????',
#  'milan': '????',
#  'malpensa': '?????????',
#  'marlon': '???????',
#  'black': '??????',
#  'sakotiya': '????????',
#  'see': '???',
#  'sheikh': '???',
#  'shabeli': '?????',
#  'dhruv': '?????',
#  'indrakarman': '??????????',
#  'portsmouth': '???????????',
#  'shrimyi': '???????',
#  'glacier': '????????',
#  'mugdala': '??????',
#  'hele': '????',
#  'joel': '????',
#  'ausment': '??????',
#  'sarfarosh': '??????',
#  'raji': '????',
#  'doctor': '??????',
#  'shaitan': '?????',
#  'aakhri': '????',
#  'muqabla': '???????',
#  'munmayi': '???????',
#  'niharika': '????????',
#  'jewel': '?????',
#  'thief': '???',
#  'tanbur': '???????',
#  'metropolitan': '????????????',
#  'sagaami': '?????',
#  'jihaan': '?????',
#  'dusri': '?????',
#  'dulhann': '??????',
#  'abhir': '????',
#  'thamarpaili': '??????????',
#  'dushmann': '??????',
#  'bhopatkar': '??????',
#  'bagdad': '?????',
#  'raatein': '?????',
#  'aduj': '????',
#  'zahir': '????',
#  'jab': '??',
#  'kisi': '????',
#  'te': '??',
#  'master': '??????',
#  'aswan': '??????',
#  'halim': '????',
#  'newberry': '????????',
#  "le'lu": "??'??",
#  'utah': '????',
#  'se': '??',
#  'hota': '???',
#  'hain': '???',
#  'bhadresh': '??????',
#  'annapurna': '??????????',
#  'morning': '?????',
#  'vivek': '?????',
#  'jimmy': '????',
#  'cook': '???',
#  'raajit': '?????',
#  'subrose': '???????',
#  'satna': '????',
#  'neelam': '????',
#  'pari': '???',
#  'triborag': '????????',
#  'barya': '?????',
#  'avion': '?????',
#  'centurian': '???????????',
#  'baki': '????',
#  'bill': '???',
#  'lorry': '????',
#  'kewin': '?????',
#  'druars': '??????',
#  'kahani': '????',
#  'fulvati': '??????',
#  'bhemasvaadi': '?????????',
#  'bejubaan': '???????',
#  'corneliya': '??????????',
#  'krishnakanth': '??????????',
#  'ketalin': '??????',
#  'dundun': '??????',
#  'bland': '??????',
#  'sarojini': '???????',
#  'bheem': '???',
#  'garjana': '??????',
#  'haphijoor': '??????',
#  'rahaman': '?????',
#  'ross': '???',
#  'pirot': '?????',
#  'rat': '??',
#  'ke': '?',
#  'raahi': '????',
#  'shaahid': '?????',
#  'anwar': '?????',
#  'sheep': '???',
#  'nounihaal': '???????',
#  'emirates': '????????',
#  'kalisi': '????',
#  'sidoni': '??????',
#  'sandhi': '????',
#  'guru': '????',
#  'dakshin': '???????',
#  'saint': '????',
#  'george': '?????',
#  'doovar': '????',
#  'wan': '??',
#  'sowgath': '?????',
#  'neda': '????',
#  'baabaa': '????',
#  'mohayiyaaddin': '???????????',
#  'haai': '???',
#  'iumgal': '????',
#  'bydaree': '?????',
#  'afshaar': '??????',
#  'rangeen': '?????',
#  'bhairav': '????',
#  'pinaak': '?????',
#  'ek': '??',
#  'shola': '????',
#  'sven': '?????',
#  'mrunalini': '????????',
#  'finoleks': '?????????',
#  'industriz': '??????????',
#  'jalandhar': '??????',
#  'vijete': '??????',
#  'husnaara': '????????',
#  'northempton': '??????????',
#  'college': '?????',
#  'bada': '???',
#  'aadimi': '????',
#  'apna': '?????',
#  'khoon': '???',
#  'white': '???',
#  'suverchala': '????????',
#  'easter': '?????',
#  'sign': '???',
#  'pablo': '??????',
#  'bay': '??',
#  'gola': '????',
#  'barood': '?????',
#  'sharayana': '??????',
#  'dushman': '?????',
#  'hatctiff': '??????',
#  'balvir': '?????',
#  'benington': '?????????',
#  'marvin': '??????',
#  'deelo': '?????',
#  'moin': '????',
#  'khaan': '???',
#  'mohiniatum': '???????????',
#  'singanhdah': '????????',
#  'sayeed': '???',
#  'fazal': '????',
#  'karim': '????',
#  'kadri': '?????',
#  'antalaya': '????????',
#  'havalimani': '??????????',
#  'fatehgad': '??????',
#  'simpro': '??????',
#  'ichu': '?????',
#  'jeyad': '?????',
#  'hapoogo': '??????',
#  'award': '??????',
#  'mursal': '?????',
#  'paida': '????',
#  'karne': '????',
#  'vaale': '????',
#  'jhoncha': '????',
#  'rogini': '??????',
#  'adil': '????',
#  'eyan': '????',
#  'makevan': '??????',
#  'natvar': '????',
#  'kantele': '???????',
#  'uma': '???????',
#  'joshi': '????',
#  'bat': '???',
#  'panchmahal': '??????',
#  'beehu': '????',
#  'kesaava': '??????',
#  'dalhaiji': '??????',
#  'group': '?????',
#  'bairi': '????',
#  'haidli': '?????',
#  'mehendi': '??????',
#  'lagi': '???',
#  'haath': '???',
#  'stuart': '????????',
#  'bhadrachalam': '????????',
#  'kalelakar': '???????',
#  'vedic': '?????',
#  'ravi': '???',
#  'ratnayake': '????????',
#  'cais': '???',
#  'deprame': '????????',
#  'shreevallabh': '?????????',
#  'karl': '?????',
#  'raugars': '??????',
#  'semyulikee': '??????????',
#  'samrendu': '???????',
#  'kurde': '?????',
#  'salil': '????',
#  'ankola': '??????',
#  'gajasya': '??????',
#  'mauriliyo': '???????',
#  'somarset': '???????',
#  'mom': '???',
#  'bradshow': '???????',
#  'ibtal': '???????',
#  'al': '??',
#  'hilaal': '?????',
#  'vivi': '????',
#  'snow': '????',
#  'shyamalata': '????????',
#  'phillip': '?????',
#  'dell': '???',
#  'maro': '????',
#  'evergreen': '????????',
#  'community': '?????????',
#  'keenan': '????',
#  'carch': '????',
#  'open': '???',
#  'door': '????',
#  'chau': '???',
#  'mahla': '?????',
#  'reliance': '???????',
#  'naichura': '????????',
#  'prasam': '??????',
#  'archardas': '?????????',
#  'harway': '??????',
#  'avardas': '?????????',
#  'lopamudra': '?????????',
#  'saeed': '???',
#  'aajaad': '????',
#  'steav': '?????',
#  'wander': '??????',
#  'najar': '???',
#  'union': '??????',
#  'pipe': '????',
#  'atttuniti': '??????????',
#  'cosmo': '??????',
#  'oil': '???',
#  'dwigt': '??????',
#  'humayrah': '???????',
#  'rameez': '????',
#  'satwik': '???????',
#  'dayton': '????',
#  'victim': '?????',
#  'custer': '?????',
#  'offenpest': '?????????',
#  'caterpillar': '????????',
#  'shriram': '???????',
#  'transfi': '????????',
#  'shiva': '????',
#  'gamma': '????',
#  'four': '???',
#  'continents': '????????????',
#  'figure': '????',
#  'skating': '????????',
#  'champions': '?????????',
#  'fuller': '????',
#  'murder': '?????',
#  'jacob': '????',
#  'aurum': '???',
#  'bareerah': '?????',
#  'madhuri': '??????',
#  'institute': '????????????',
#  'rocky': '????',
#  'ananya': '??????',
#  'bar': '??',
#  'chale': '???',
#  'aao': '???',
#  'gaverai': '?????',
#  'somkanta': '????????',
#  'internet': '???????',
#  'initiative': '?????????',
#  'japan': '?????',
#  ...}

# %%
tran_en_hi_file1 = open("crowd_transliterations.hi-en.txt", 'r', encoding="utf8")
tran_en_hi_file2 = open("Hindi-WordTransliterationPairs.txt", 'r', encoding="utf8")
lines1 = tran_en_hi_file1.readlines()
lines2 = tran_en_hi_file2.readlines()
en_hi_transliterate = {}
for line in lines1:
    en,hi = line.split()
    en_hi_transliterate[en.lower()] = hi
for line in lines2:
    en,hi = line.split()
    en_hi_transliterate[en.lower()] = hi
en_hi_transliterate
# Out:
# {'hajagiree': 'हजगिरी',
#  'chekaanv': 'चेकॉव',
#  'spinagaarn': 'स्पिनगार्न',
#  'medal': 'मेडल',
#  'chetthinaad': 'चेत्तिनाद',
#  'hari': 'हरि',
#  'bhoomi': 'भूमि',
#  'yaanhmsan': 'थॉम्सन',
#  'hanumaan': 'हनुमान',
#  'abhinetri': 'अभिनेत्री',
#  'to': 'तो',
#  'sikkim': 'सिक्किम',
#  'abdus': 'अब्दुस',
#  'salam': 'सलाम',
#  'alvar': 'अलवर',
#  'kapil': 'कपिल',
#  'dev': 'देव',
#  'baaflayer': 'बार्फ्लेयर',
#  'capilano': 'कॅपीलानो',
#  'suspension': 'सस्पेंशन',
#  'graham': 'ग्राहम',
#  'stephenson': 'स्टीवंसन',
#  'auckland': 'ऑकलैंड',
#  'art': 'आर्ट',
#  'museum': 'म्युज़ियम',
#  'kamlesh': 'कमलेश',
#  'effi': 'एफी',
#  'awards': 'अवार्ड्\u200dस',
#  'warren': 'वारेन',
#  'visneski': 'विसनेस्की',
#  'brus': 'ब्रूस',
#  'aigar': 'एगर',
#  'jaun': 'जाऊं',
#  'miltan': 'मिल्टन',
#  'ai': 'आई',
#  'yaad': 'यार',
#  'teri': 'तेरि',
#  'samad': 'समद',
#  'ernaa': 'एर्ना',
#  'shree': 'श्री',
#  'ram': 'रम',
#  'bharat': 'भारत',
#  'milap': 'मिलाप',
#  'roci': 'रॉक्सी',
#  'kedy': 'केडी',
#  'madihah': 'मदिहाह',
#  'aahlad': 'आह्लाद',
#  'bornham': 'बॉर्नहेम',
#  'fort': 'फोर्ट',
#  'erma': 'एर्मा',
#  'mera': 'मेर',
#  'lalkar': 'ललकार',
#  'apoorva': 'अपूर्व',
#  'civilla': 'सिविला',
#  'ranchi': 'रांची',
#  'kapila': 'कपिला',
#  'modesti': 'मोडेस्टी',
#  'elan': 'एलान',
#  'vels': 'वेल्स',
#  'abhishok': 'अभिशोक',
#  'bedard': 'बेदर्द',
#  'jamana': 'जमना',
#  'kya': 'क्या',
#  'jaane': 'जानी',
#  'aaditya': 'आदित्य',
#  'savitshri': 'सवितश्री',
#  'abot': 'एबॉट',
#  'india': 'हिंदुस्तान',
#  'irfan': 'इरफान',
#  'samedemose': 'सेंटीमोस',
#  'chaarsee': 'चांसी',
#  'mahafhooj': 'महाभुज',
#  'gardi': 'ग्रंडी',
#  'kofare': 'कॉफरे',
#  'd': 'द',
#  'perood': 'पेरोट',
#  'kovlin': 'कॉलिन',
#  'crofd': 'क्रोफ्ट',
#  'tirupati': 'तिरुपती',
#  'bhatti': 'भट्टी',
#  'gurdwara': 'गुरूद्वारा',
#  'betma': 'बेटमा',
#  'sahib': 'साहिब',
#  'zapata': 'ज़पाटा',
#  'bhanwar': 'भँवर',
#  'passenger': 'राही',
#  'gambler': 'जुआरी',
#  'adas': 'आदस',
#  'ilenaabaad': 'इलेनाबाद',
#  'varjeeniya': 'वर्जीनिया',
#  'reel': 'रील',
#  'intikaam': 'इंतिक़ाम',
#  'kee': 'के',
#  'aag': 'आग',
#  'maijar': 'मैज़र',
#  'arawalee': 'अरावली',
#  'rod': 'रॉड',
#  'thayer': 'थायेर',
#  'sentaems': 'सेंटाइम्स',
#  'lut': 'लुत',
#  'shyama': 'श्यामा',
#  'wilkin': 'विल्किन',
#  'darvin': 'डार्विन',
#  'yatim': 'यतीम',
#  'john': 'जॉन',
#  'pan': 'पन',
#  'gua': 'गुआ',
#  'sipinkuga': 'सिपीकुंग',
#  'sekhva': 'सेखवा',
#  'aajam': 'आज़म',
#  'shakti': 'शक्ति',
#  'gordhan': 'गोरधन',
#  'chandresh': 'चंद्रेश',
#  'water': 'पानी',
#  'polo': 'पोलो',
#  'aakhiri': 'आखिरी',
#  'adalat': 'अदालत',
#  'university': 'यूनिवर्सिटी',
#  'christopher': 'क्रिस्टोफर',
#  'reeve': 'रीव',
#  'amriteshaya': 'अमृतेशय',
#  'vermillion': 'वर्मिलियन',
#  'bellerophon': 'बेलरोफोन',
#  'nasa': 'नासा',
#  'for': 'फॉर',
#  'exceptional': 'एक्सेप्शनल',
#  'off': 'ऑफ',
#  'colorado': 'कोलोरॅडो',
#  'denvik': 'दैन\u200dिक',
#  'bhaskar': 'भास्कर',
#  'dugirala': 'दुगिराला',
#  'pyaar': 'प्यर',
#  'ki': 'कि',
#  'baji': 'बाजी',
#  'kanak': 'कनक',
#  'maulana': 'मौलाना',
#  'scientific': 'साइंटीफिक',
#  'achievement': 'अचीवमेंट',
#  'abdul': 'अब्दुल',
#  'tawwab': 'तव्वाब',
#  'palm': 'पाम',
#  'spring': 'स्प्रिंग',
#  'henry': 'हनरी',
#  'williams': 'विल्यम्स',
#  'bodan': 'बोडन',
#  'kalam': 'कलम',
#  'azaad': 'आज़ाद',
#  'patekar': 'पाटेकर',
#  'rebaba': 'रेबाबा',
#  'shark': 'शार्क',
#  'naugty': 'नॉटी',
#  'boy': 'बॉय',
#  'mesosphere': 'मीसोस्फीयर',
#  'dhanshyan': 'घनश्याम',
#  'sun': 'सुन',
#  'peolo': 'पेओलो',
#  'me': 'मे',
#  'sudesh': 'सुदेश',
#  'track': 'ट्रैक',
#  'end': 'एण्ड',
#  'field': 'फील्ड',
#  'ghamand': 'घमंड',
#  'juma': 'जुमा',
#  'centurion': 'सेंचूरियन',
#  'khalid': 'खालिद',
#  'mashoodah': 'मशूद',
#  'anberdekr': 'आंबर्डेकर',
#  'ghaare': 'घारे',
#  'perin': 'पेरीन',
#  'over': 'ओवर',
#  'imposhsible': 'असंभव',
#  'mevaaraam': 'मेवाराम',
#  'divarath': 'दिवारथ',
#  'guljar': 'गुल्जार',
#  'andrew': 'एण्ड्रयू',
#  'flintoff': 'फ्लिंटॉफ',
#  'wilmet': 'विल्मेट',
#  'blonde': 'गोरा',
#  'vanburn': 'वैनबर्न',
#  'holder': 'होल्डर',
#  'season': 'ऋतु',
#  'treacherous': 'बेवफ़ा',
#  'chaina': 'चैना',
#  'national': 'नेशनल',
#  'rajendramohan': 'राजेंद्रमोहन',
#  'sadanand': 'सदानंद',
#  'dholpur': 'धौलपुर',
#  'nasrin': 'नसरीन',
#  'zamaana': 'जमाना',
#  'order': 'ऑडर',
#  'sikatuna': 'सिकाटुना',
#  'kaala': 'ख़ाला',
#  'dhandha': 'धंधा',
#  'petroleum': 'पेट्रोलियम',
#  'barnet': 'बार्नेट',
#  'vedgya': 'वेदज्ञ',
#  'parwez': 'परवेज़',
#  'gohpur': 'गोहपुर',
#  'chunnilaal': 'चुन्नीलाल',
#  'nadere': 'नदेरे',
#  'ireland': 'आयरलैंड',
#  'bansuri': 'बंसुरी',
#  'sewan': 'सेवन',
#  'gore': 'गोरे',
#  'log': 'लोग',
#  'rock': 'रॉक',
#  'lake': 'लाके',
#  'baspist': 'बैपटिस्ट',
#  'pakararima': 'पाकाराइमा',
#  'mahadevi': 'महादेवी',
#  'verma': 'वर्मा',
#  'jatan': 'जतन',
#  'braveward': 'ब्रेवार्ड',
#  'mails': 'माइल्स',
#  'aenaadaayar': 'एनाडायर',
#  'katak': 'कटक',
#  'zyoorik': 'ज़्यूरिक',
#  'faainaanshiyal': 'फ़ाइनेंशियल',
#  'sarvisez': 'सर्विसेज़',
#  'mishelin': 'मिशेलिन',
#  'varta': 'वार्ता',
#  'gullapoor': 'गुल्लपूर',
#  'brita': 'ब्रिट',
#  'gaaye': 'गाएँ',
#  'vittal': 'व्हिट्टल',
#  'empero': 'इंपेरो',
#  'jaagran': 'जागरण',
#  'samprprith': 'सम्प्रीत',
#  'florus': 'फ्लोरस',
#  'julia': 'जुलिया',
#  'child': 'चाइल्ड',
#  'corporation': 'कॉर्पोरेशन',
#  'bank': 'बैंक',
#  'dalel': 'दलेल',
#  'river': 'रिवर',
#  'phoenix': 'फ़ोनिक्स',
#  'swanna': 'सवान्ना',
#  'chandril': 'चंद्रिल',
#  'hisham': 'हिशाम',
#  'syed': 'सय्यद',
#  'kirmani': 'किरमानी',
#  'balawali': 'बलावाली',
#  'siddheshwari': 'सिद्धेश्वरी',
#  'varship': 'वर्शिप',
#  'sentar': 'सेन्टर',
#  'kaiptan': 'कैप्टन',
#  'bairee': 'बैरी',
#  'shikhkar': 'शिखर',
#  'par': 'पार',
#  'gurjeet': 'गुरजीत',
#  'aelsaas': 'एल्सास',
#  'seviyar': 'सेवियर',
#  'baanchar': 'बॉचर',
#  'memoriyal': 'मेमोरियल',
#  'praais': 'प्राइज़',
#  'valt': 'वॉल्ट',
#  'dijani': 'डिज़्नी',
#  'kritendan': 'क्रिटेंडन',
#  'kalevari': 'क्लेवरी',
#  'baiptist': 'बैपटिस्ट',
#  'beljiyam': 'बेल्जियम',
#  'intal': 'इंटल',
#  'bijnes': 'बिज़नेस',
#  'kash': 'काश',
#  'sautan': 'सौतन',
#  'beti': 'बेती',
#  'steve': 'स्टीव',
#  'rikson': 'रिक्सन',
#  'yashima': 'यशिमा',
#  'milicent': 'मिलिसेंट',
#  'saya': 'साया',
#  'machines': 'मशीन्स',
#  'mahageet': 'महागीत',
#  'charles': 'चार्ल्स',
#  'kauvantri': 'कॉवेंट्री',
#  'sheila': 'शीला',
#  'khudra': 'खुदा',
#  'kasam': 'कसम',
#  'anuva': 'अनुवा',
#  'makil': 'मक़िल',
#  'liyouna': 'लियोना',
#  'baintula': 'बन्दुला',
#  'varnapura': 'वर्नापुरा',
#  'thnavant': 'धनवंत',
#  'iklawit': 'ग्लाइड',
#  'myritaim': 'मैरीटाइम',
#  'merit': 'मेरिट',
#  'anhkom': 'आँखों',
#  'harshele': 'हरशेले',
#  'gibs': 'गिब्स',
#  'banujaah': 'बनुजाह',
#  'damount': 'डॉमोंट',
#  'basmaah': 'बस्माह',
#  'endi': 'एण्डी',
#  'paicroft': 'पाइक्रोफ्ट',
#  'gender': 'ज़ेंडर',
#  'pinkwillow': 'पिंक्वीलो',
#  'may': 'मय',
#  'santa': 'सेंटा',
#  'mariya': 'मारिया',
#  'stevan': 'स्टीवन',
#  'playvin': 'प्लेविन',
#  'takaniya': 'डाकनिया',
#  'talav': 'तलाव',
#  'abhijvala': 'अभिज्वाला',
#  'luckjambark': 'लक्ज़ेम्बर्ग',
#  'zeeda': 'सिटी',
#  'yoonivarsiti': 'यूनिवर्सिटी',
#  'kalej': 'कॉलेज',
#  'landan': 'लंदन',
#  'gehamar': 'गेहमर',
#  'priyathaa': 'प्रियशा',
#  'teleree': 'टेलेरी',
#  'chchindavaadaa': 'छिंदवाड़ा',
#  'jankshan': 'जंक्शन',
#  'malik': 'मलिक',
#  'raiphelo': 'रैफेलो',
#  'phoebe': 'फोएबे',
#  'cage': 'पिंजरा',
#  'amer': 'आमेर',
#  'devgan': 'देवगन',
#  'road': 'रोड',
#  'mujahid': 'मुजाहिद',
#  'jamshed': 'जमशेद',
#  'suzuki': 'सुज़ुकी',
#  'motor': 'मोतोर',
#  'broadwater': 'ब्रॉडवाटर',
#  'bagri': 'बागरी',
#  'sajanpure': 'सज्जनपुर',
#  'niramay': 'निरामय',
#  'hum': 'हुम',
#  'tum': 'तम',
#  'aur': 'और',
#  'wo': 'वो',
#  'amanat': 'अमानत',
#  'ichhita': 'इच्छिता',
#  'jaiki': 'जैकी',
#  'devdharkar': 'देवधरकर',
#  'hasan': 'हसन',
#  'shaik': 'शेक',
#  'haimdres': 'हैंड्\u200dस',
#  'agar': 'अगर',
#  'na': 'ना',
#  'hote': 'होते',
#  'adhikar': 'अधिकार',
#  'vinodini': 'विनोदिनी',
#  'amlaai': 'अम्लाई',
#  'debashish': 'देबाशीश',
#  'kaushik': 'कौशिक',
#  'somanshu': 'सोमांशु',
#  'karsan': 'कार्सन',
#  'ghavri': 'घावरी',
#  'opto': 'ऑप्टो',
#  'circuits': 'सर्किट्स',
#  'noma': 'नोमा',
#  'aacharyasuta': 'आचार्यसुता',
#  'suraj': 'सुरज',
#  'gyanda': 'ज्ञानदा',
#  'roshan': 'रोशन',
#  'jurangpathi': 'जुरंगपथी',
#  'jaisi': 'जैसी',
#  'james': 'जेम्स',
#  'aage': 'आगे',
#  'badho': 'बढ़ो',
#  'abhayprad': 'अभयप्रद',
#  'prize': 'प्राइज़',
#  'literature': 'लिट्रेचर',
#  'waqt': 'वक़्त',
#  'deewar': 'दीवार',
#  'ahmed': 'अहमद',
#  'kamaal': 'कमाल',
#  'jawaharlal': 'जवाहरलाल',
#  'nehru': 'नेहरु',
#  'tirupatisaram': 'तिरुपतीसराम',
#  'asif': 'आसिफ',
#  'mahmood': 'महमूद',
#  'triptaa': 'तृप्ता',
#  'raveesh': 'रवीश',
#  'berish': 'बेरिस',
#  'dam': 'दम',
#  'kashef': 'कशेफ',
#  'saiful': 'सैफुल',
#  'islam': 'इस्लाम',
#  'biswesvraya': 'विश्वेसवराया',
#  'preet': 'प्रीत',
#  'not': 'नोट',
#  'the': 'लिया',
#  'reet': 'रीत',
#  'supreme': 'सुप्रीम',
#  'petro': 'पेट्रो',
#  'pearsa': 'पेअरसैल',
#  'film': 'फ़िल्म',
#  'he': 'हे',
#  'manthan': 'मंथन',
#  'akram': 'अकरम',
#  'sawal': 'सवाल',
#  'ayyappan': 'अय्यप्पन',
#  'baseera': 'बसीर',
#  'vinugopal': 'विणुगोपाल',
#  'raav': 'राव',
#  'nimish': 'निमिश',
#  'aap': 'अप',
#  'marji': 'मर्जी',
#  'kvenacho': 'क्वेनाचो',
#  'lokesh': 'लोकेश',
#  'aabhir': 'आभीर',
#  'nippon': 'निप्पॉन',
#  'mining': 'माइनिंग',
#  'holdings': 'होल्डिंग्स',
#  'havange': 'हवांगे',
#  'priks': 'प्रिक्स',
#  'medisis': 'मेडिसिस',
#  'lusander': 'ल्यूसेंडर',
#  'formidable': 'फोर्मिडेबल',
#  'jodi': 'जोदि',
#  'kanyalal': 'कन्हैयालाल',
#  'kin': 'किन',
#  'salaam': 'सलाम',
#  'kelkar': 'केलकर',
#  'chelsiyaa': 'चेल्सिया',
#  'zizzee': 'ज़िज़ी',
#  'jeeval': 'जीवल',
#  'vaasanti': 'वासंती',
#  'dharam': 'धरम',
#  'veer': 'वीर',
#  'galenis': 'ग्लेनिस',
#  'paanl': 'पॉल',
#  'varlis': 'व्रेलिस',
#  'greeh': 'ग्रीक',
#  'hastreet': 'ह\u200dिस्ट्री',
#  'forte': 'फोर्ट',
#  'worth': 'वर्थ',
#  'teja': 'तेजा',
#  'tejal': 'तेजल',
#  'khidaike': 'खिड़की',
#  'kunti': 'कुंती',
#  'keena': 'कीना',
#  'yasmin': 'यास्मिन',
#  'madhuchanda': 'मधुचन्दा',
#  'javait': 'जवाद',
#  'dayjan': 'टेजॉन',
#  'javan': 'जवाँ',
#  'kioto': 'क्योटो',
#  'moskva': 'मोस्क्वा',
#  'anjane': 'अनजाने',
#  'mohammad': 'मोहम्मद',
#  'madani': 'मदानी',
#  'miya': 'मिया',
#  'asrafi': 'अशरफी',
#  'ashapurna': 'आशापूर्णा',
#  'devi': 'देवी',
#  'sarey': 'सरेय',
#  'luck': 'किस्मत',
#  'violence': 'वॉलेंसा',
#  'trigental': 'ट्रेगैन्टल',
#  'georgia': 'जॉर्जिया',
#  'osmund': 'ओसमंड',
#  'nabraska': 'नेब्रास्का',
#  'bhadran': 'भद्रन',
#  'shoab': 'शोएब',
#  'kaviraj': 'कविराज',
#  'hainis': 'हॉयनिस',
#  'bhilwara': 'भीलवाड़ा',
#  'hujes': 'ह्युजेस',
#  'hare': 'हरे',
#  'kaanch': 'कांच',
#  'chudiyna': 'चुड़ियाँ',
#  'jaindra': 'ज़ैंड्रा',
#  'jeki': 'जैकी',
#  'baba': 'बब',
#  'bule': 'बुले',
#  'shah': 'शाह',
#  'shaikh': 'शेख',
#  'chilli': 'चिल्ली',
#  'divine': 'द\u200dिव्य',
#  'nagar': 'नागर',
#  'done': 'डन',
#  'shiv': 'शिव',
#  'raatri': 'रात्रि',
#  'nagma': 'नगमा',
#  'deep': 'दीप',
#  'daasgupta': 'दासगुप्ता',
#  'banani': 'बनानी',
#  'sudarshna': 'सुदर्शना',
#  'tayibaaha': 'तय्यिबाह',
#  'banaahi': 'बनाही',
#  'bhagavaanpura': 'भगवानपुरा',
#  'anokha': 'अनोखा',
#  'rishta': 'रिश्ता',
#  'scent': 'सेंट',
#  'meri': 'मेरि',
#  'naseer': 'नसीर',
#  'duff': 'डफ',
#  'ka': 'खा',
#  'phaamarn': 'पॉमर्न',
#  'gurudwara': 'गुरूद्वारा',
#  'tibbi': 'टिब्बी',
#  'saahib': 'साहिब',
#  'tarkkas': 'तरकस',
#  'mout': 'मौत',
#  'kaa': 'खा',
#  'tufaan': 'तूफ़ां',
#  'harraarey': 'हरारे',
#  'jeraald': 'जेरॉल्ड',
#  'goarade': 'गौरडे',
#  'lele': 'लेले',
#  'darbar': 'दरबार',
#  'mutti': 'मुत्ती',
#  'nafarat': 'नफ़रत',
#  'aanhdhi': 'आँधी',
#  'gaay': 'गाय',
#  'dog': 'डॉग',
#  'sibojiryam': 'सीबोर्जियम',
#  'lalitkishore': 'ललितकिशोर',
#  'sugtiy': 'सुगतीय',
#  'sabak': 'सबक',
#  'hatyare': 'हत्यारे',
#  'khemchand': 'खेमचंद',
#  'naalko': 'नाल्को',
#  'bayar': 'बायर',
#  'badavi': 'बदावी',
#  'devgam': 'देवगम',
#  'waltars': 'वाल्टर्स',
#  'afsana': 'अफ़सान',
#  'slasen': 'स्लेसेन',
#  'gas': 'गैस',
#  'shungare': 'शुंगारे',
#  'kaheesha': 'कहीशा',
#  'smith': 'स्मिथ',
#  'shekel': 'शेकेल',
#  'josaf': 'जोसफ',
#  'stelin': 'स्टेलिन',
#  'hinge': 'हिंगे',
#  'bankiyaw': 'बैंकियाओ',
#  'liyonardo': 'लियोनार्डो',
#  'kepriyo': 'कैप्रियो',
#  'garnet': 'गर्नेट',
#  'krugar': 'क्रूगर',
#  'war': 'वर',
#  'chittar': 'चित्तर',
#  'indian': 'इंड\u200dियन',
#  'omar': 'ओमर',
#  'kheyyam': 'खैय्यम',
#  'players': 'प्लेयर्स',
#  'formalisis': 'फ़ार्माएक्सिस',
#  'limited': 'लिमिटेड',
#  'pawaskar': 'पावसकर',
#  'faninath': 'फणिनाथ',
#  'edlin': 'एडलिन',
#  'sant': 'सन्त',
#  'xyanershwar': 'ज्ञानेश्वर',
#  'raghvendra': 'राघवेंद्र',
#  'natu': 'नातू',
#  'cheboob': 'चेकोब',
#  'babu': 'बाबू',
#  'memon': 'मेमन',
#  'express': 'एक्सप्रेस',
#  'itochu': 'इतोचु',
#  'atroli': 'अत्रौली',
#  'sapna': 'सपना',
#  'taisir': 'तैसिर',
#  'murre': 'मुर्रे',
#  'gudwin': 'गुडविन',
#  'dark': 'डर्क',
#  'street': 'स्ट्रेट',
#  'sikkrapts': 'स्क्रिप्ट्स',
#  'aakash': 'आकाश',
#  'frank': 'फ़्रैंक',
#  'raj': 'रज',
#  'tilak': 'तिलक',
#  'laakirn': 'लार्किन',
#  'riyaan': 'रियान',
#  'vanmata': 'वनमाता',
#  'international': 'इंटरनेशनल',
#  'paper': 'पेपर',
#  'jet': 'जेट',
#  'airways': 'एयरवेज़',
#  'anadyant': 'अनाद्यंत',
#  'gujjar': 'गुज्जर',
#  'banba': 'बैंबा',
#  'actress': 'एक्ट्रेस',
#  'kyun': 'क्युन',
#  'bani': 'बानी',
#  'hasina': 'हसीना',
#  'maan': 'मां',
#  'iravti': 'इरावती',
#  'makisma': 'मक्सिमा',
#  'sumitra': 'सुमित्रानंदन',
#  'vishya': 'विषया',
#  'hind': 'हिन्द',
#  'edakad': 'इदाक्क्ड़',
#  'herve': 'हिरवे',
#  'derrick': 'डेरिक',
#  'more': 'मोरी',
#  'jaegi': 'जाएगी',
#  'amarp': 'अमरप',
#  'lawarris': 'लावारिस',
#  'fakhrh': 'फख्र',
#  'roj': 'रोज',
#  'kennedy': 'केनेडी',
#  'arsikeri': 'अरसिकेरी',
#  'junction': 'जंक्शन',
#  'detective': 'डिटेक्टिव',
#  'janu': 'जानू',
#  'riverside': 'रिवरसाइड',
#  'marsabit': 'मारसाबिट',
#  'and': 'और',
#  'reserve': 'रिज़र्व',
#  'jagmohan': 'जगमोहन',
#  'sanjeevan': 'संजीवन',
#  'mahindra': 'महिंद्रा',
#  'yujin': 'युजिन',
#  'mangalore': 'मैंगलोर',
#  'chemicals': 'केमिकल्स',
#  'mishol': 'मिशेल',
#  'london': 'लंदन',
#  'dublin': 'डब्ल\u200dिन',
#  'writers': 'राइटर्स',
#  'do': 'दो',
#  'aanhgee': 'आँखें',
#  'enig': 'एनीज',
#  'bhell': 'भेल',
#  'myginsheyam': 'मैग्निशियम',
#  'ranghaava': 'रंधावा',
#  'looyisa': 'लुइसा',
#  'kep': 'केप',
#  'code': 'कॉड',
#  'faded': 'फाटेट',
#  'neenth': 'नींद',
#  'hamare': 'हमरे',
#  'khyalab': 'ख्वाब',
#  'tomhara': 'तुम्हारे',
#  'neris': 'नेरीस',
#  'townsand': 'टाउनसेंड',
#  'bawli': 'बाउली',
#  'chunauti': 'चुनौती',
#  'ghatprabha': 'घाटप्रभा',
#  'brook': 'ब्रूक',
#  'chandiya': 'चंदिया',
#  'ginis': 'ग\u200dिनीज',
#  'world': 'वर्ल्ड',
#  'offf': 'ऑफ',
#  'records': 'रेकॉर्ड्स',
#  'muquabla': 'मुकाबला',
#  'abhimand': 'अभिमन्द',
#  'linel': 'लाइनेल',
#  'wanker': 'वॉकर',
#  'shubhang': 'शुभांग',
#  'delta': 'डेल्टा',
#  'ear': 'ईयर',
#  'lains': 'लाइन्स',
#  'thomson': 'थॉमसन',
#  'jack': 'जैक',
#  'nicholson': 'निकोलसन',
#  'mohsin': 'मोहसिन',
#  'khan': 'खान',
#  'vidya': 'विद्या',
#  'vardhak': 'वर्धक',
#  'sang': 'सन्ग',
#  'high': 'हाई',
#  'school': 'स्कूल',
#  'bangalore': 'बैंगलोर',
#  'jurat': 'जुर्रत',
#  'haikla': 'हेक्ला',
#  'ajay': 'अजय',
#  'krushna': 'कृष्णा',
#  'grant': 'ग्रांट',
#  'breadburn': 'ब्रैडबर्न',
#  'saaransh': 'सारांश',
#  'elita': 'एलिटा',
#  'rahima': 'रहीम',
#  'ajmat': 'अज़्मत',
#  'yomhas': 'थॉमस',
#  'army': 'आर्मी',
#  'public': 'पबलिक',
#  'new': 'नेव',
#  'delhi': 'डेल्ही',
#  'garhi': 'गर्ही',
#  'maanikpur': 'मानिकपुर',
#  'adam': 'अदम',
#  'kaavli': 'कावली',
#  'price': 'प्राइस',
#  'glora': 'ग्लोरा',
#  'benito': 'बेनिटो',
#  'musolini': 'मुसोलिनी',
#  'jaysudha': 'जयसुधा',
#  'federal': 'फ़ेडेरल',
#  'templo': 'टेम्पलो',
#  'day': 'डे',
#  'pen': 'पेन',
#  'royal': 'रॉयल',
#  'academy': 'एकेडमी',
#  'of': 'ऑफ',
#  'arts': 'आर्ट्स',
#  'julinka': 'जूलिन्का',
#  'bats': 'बेट्स',
#  'anikuttan': 'अनइकुट्\u200dटम',
#  'reservoir': 'रिज़रवायर',
#  'david': 'डेविड',
#  'albanjaa': 'अलबन्ज़ा',
#  'a': 'अ',
#  'builinggul': 'बिलींगुअल',
#  'siberut': 'सिबेरुट',
#  'hamdi': 'हम्दी',
#  'jeend': 'जींद',
#  'dream': 'ड्रीम',
#  'girl': 'गर्ल',
#  'biwi': 'बीवी',
#  'lloyd': 'लॉयडचिलीज़',
#  'blhind': 'अंधों',
#  'suwo': 'सूवो',
#  'aftab': 'आफताब',
#  'radha': 'रधा',
#  'sita': 'सीता',
#  'khubgawkar': 'खुबगावकर',
#  'prabhas': 'प्रभास',
#  'great': 'ग्रेट',
#  'sandy': 'सैंडी',
#  'nalayak': 'नालायक',
#  'richard': 'रिचर्ड',
#  'bartan': 'बर्तन',
#  'newbery': 'न्यूबेरी',
#  'honour': 'हॉनर',
#  'milan': 'मिलन',
#  'malpensa': 'मालपेन्सा',
#  'marlon': 'मार्लोन',
#  'black': 'ब्लैकी',
#  'sakotiya': 'स्कॉटिया',
#  'see': 'सेए',
#  'sheikh': 'शेख',
#  'shabeli': 'शबेली',
#  'dhruv': 'ध्रुव',
#  'indrakarman': 'इंद्रकर्मण',
#  'portsmouth': 'पोर्ट्समाउथ',
#  'shrimyi': 'श्रीमयी',
#  'glacier': 'ग्लेशियर',
#  'mugdala': 'मग्दला',
#  'hele': 'हेले',
#  'joel': 'जोएल',
#  'ausment': 'ऑसमेंट',
#  'sarfarosh': 'सरफरोश',
#  'raji': 'राज़ी',
#  'doctor': 'डॉक्टर',
#  'shaitan': 'शैतान',
#  'aakhri': 'आखरी',
#  'muqabla': 'मुकाबला',
#  'munmayi': 'मृण्मयी',
#  'niharika': 'निहारिका',
#  'jewel': 'ज्वेल',
#  'thief': 'चोर',
#  'tanbur': 'तान्बूर',
#  'metropolitan': 'मैट्रोपॉलिटन',
#  'sagaami': 'सगामी',
#  'jihaan': 'जिहान',
#  'dusri': 'दूसरी',
#  'dulhann': 'दुल्हन',
#  'abhir': 'अभीर',
#  'thamarpaili': 'थर्मोपाइली',
#  'dushmann': 'दुश्मन',
#  'bhopatkar': 'भोपटकर',
#  'bagdad': 'बगदाद',
#  'raatein': 'रातें',
#  'aduj': 'अदुज़',
#  'zahir': 'ज़हीर',
#  'jab': 'जा',
#  'kisi': 'किसि',
#  'te': 'ते',
#  'master': 'उस्ताद',
#  'aswan': 'अस्वान',
#  'halim': 'हलीम',
#  'newberry': 'न्यूबेरी',
#  "le'lu": "लु'लु",
#  'utah': 'उटाह',
#  'se': 'सी',
#  'hota': 'होत',
#  'hain': 'हैन',
#  'bhadresh': 'भद्रेश',
#  'annapurna': 'अन्नपूर्णा',
#  'morning': 'सवेरा',
#  'vivek': 'विवेक',
#  'jimmy': 'जिमी',
#  'cook': 'कुक',
#  'raajit': 'राजित',
#  'subrose': 'सुब्रोस',
#  'satna': 'सतना',
#  'neelam': 'नीलम',
#  'pari': 'परि',
#  'triborag': 'त्रिबोरघ',
#  'barya': 'बर्या',
#  'avion': 'एवियन',
#  'centurian': 'सेंच्यूरियन',
#  'baki': 'बाकी',
#  'bill': 'बिल',
#  'lorry': 'लॉरी',
#  'kewin': 'केविन',
#  'druars': 'डुअर्स',
#  'kahani': 'कहनी',
#  'fulvati': 'फूलवती',
#  'bhemasvaadi': 'भेमस्वादी',
#  'bejubaan': 'बेजुबां',
#  'corneliya': 'कोर्नेलिया',
#  'krishnakanth': 'कृष्णकांता',
#  'ketalin': 'कैटलिन',
#  'dundun': 'डुनडुन',
#  'bland': 'ब्लांड',
#  'sarojini': 'सरोजिनी',
#  'bheem': 'भीम',
#  'garjana': 'गर्जना',
#  'haphijoor': 'हफिज़ुर',
#  'rahaman': 'रहमान',
#  'ross': 'रॉस',
#  'pirot': 'पीरॉट',
#  'rat': 'रत',
#  'ke': 'क',
#  'raahi': 'राहि',
#  'shaahid': 'शाहिद',
#  'anwar': 'अन्वर',
#  'sheep': 'शीप',
#  'nounihaal': 'नौनिहाल',
#  'emirates': 'एमीरेट्स',
#  'kalisi': 'कलसी',
#  'sidoni': 'सिडोनी',
#  'sandhi': 'संधि',
#  'guru': 'गुरु',
#  'dakshin': 'दक्षिणा',
#  'saint': 'सेंट',
#  'george': 'जॉर्ज',
#  'doovar': 'टॉवर',
#  'wan': 'वन',
#  'sowgath': 'सौगात',
#  'neda': 'निदा',
#  'baabaa': 'बाबा',
#  'mohayiyaaddin': 'मुहइयाद्दीन',
#  'haai': 'हाइ',
#  'iumgal': 'एंगल',
#  'bydaree': 'बैटरी',
#  'afshaar': 'अफ्शां',
#  'rangeen': 'रंगीन',
#  'bhairav': 'भैरव',
#  'pinaak': 'पिनाक',
#  'ek': 'एक',
#  'shola': 'शोला',
#  'sven': 'स्वैन',
#  'mrunalini': 'मृणालिनी',
#  'finoleks': 'फ़िनोलेक्स',
#  'industriz': 'इंडस्ट्रीज़',
#  'jalandhar': 'जालंधर',
#  'vijete': 'विजेती',
#  'husnaara': 'हुस्नआरा',
#  'northempton': 'नार्थएंपटन',
#  'college': 'कॉलेज',
#  'bada': 'बढ़ा',
#  'aadimi': 'आदमी',
#  'apna': 'अप्ना',
#  'khoon': 'खून',
#  'white': 'वैट',
#  'suverchala': 'सुवर्चला',
#  'easter': 'ईस्टर',
#  'sign': 'सैन',
#  'pablo': 'पाब्लो',
#  'bay': 'बे',
#  'gola': 'गोला',
#  'barood': 'बारूद',
#  'sharayana': 'शरण्या',
#  'dushman': 'दुशमन',
#  'hatctiff': 'हॉचटिफ़',
#  'balvir': 'बलवीर',
#  'benington': 'बेनिंग्टन',
#  'marvin': 'मर्विन',
#  'deelo': 'डिलों',
#  'moin': 'मोइन',
#  'khaan': 'खान',
#  'mohiniatum': 'मोहिनीअट्टम',
#  'singanhdah': 'स्निग्धा',
#  'sayeed': 'सईद',
#  'fazal': 'फज़्ल',
#  'karim': 'करीम',
#  'kadri': 'क़ादरी',
#  'antalaya': 'अंताल्या',
#  'havalimani': 'हावालीमानी',
#  'fatehgad': 'फतेहगढ़',
#  'simpro': 'स्पिरो',
#  'ichu': 'इक्षु',
#  'jeyad': 'जियाद',
#  'hapoogo': 'ह्यूगो',
#  'award': 'अवार्ड',
#  'mursal': 'मुरसल',
#  'paida': 'पैदा',
#  'karne': 'करने',
#  'vaale': 'वाले',
#  'jhoncha': 'ज़ोचा',
#  'rogini': 'रोज़ीना',
#  'adil': 'अदिल',
#  'eyan': 'इयान',
#  'makevan': 'मैकवेन',
#  'natvar': 'नटवर',
#  'kantele': 'कैनटिले',
#  'uma': 'उमाशंकर',
#  'joshi': 'जोशी',
#  'bat': 'बात',
#  'panchmahal': 'पंचमहल',
#  'beehu': 'बीहू',
#  'kesaava': 'केसावा',
#  'dalhaiji': 'डलहैज़ी',
#  'group': 'ग्रुप',
#  'bairi': 'बैरी',
#  'haidli': 'हैडली',
#  'mehendi': 'महेंडी',
#  'lagi': 'लगि',
#  'haath': 'हात',
#  'stuart': 'स्टुअर्ट',
#  'bhadrachalam': 'भद्राचलम',
#  'kalelakar': 'कालेलकर',
#  'vedic': 'वैदिक',
#  'ravi': 'रवि',
#  'ratnayake': 'रत्नायके',
#  'cais': 'कैस',
#  'deprame': 'डेपॉर्मे',
#  'shreevallabh': 'श्रीवल्लभ',
#  'karl': 'कार्ल',
#  'raugars': 'रॉगर्स',
#  'semyulikee': 'सेम्युलिकी',
#  'samrendu': 'समरेंदु',
#  'kurde': 'कुरडे',
#  'salil': 'सलिल',
#  'ankola': 'अंकोला',
#  'gajasya': 'गजस्या',
#  'mauriliyo': 'मौरिलिओ',
#  'somarset': 'सोमरसेट',
#  'mom': 'मोम',
#  'bradshow': 'ब्रेडशॉ',
#  'ibtal': 'इब्तिहल',
#  'al': 'अल',
#  'hilaal': 'हिलाल',
#  'vivi': 'विवी',
#  'snow': 'स्नो',
#  'shyamalata': 'श्यामलता',
#  'phillip': 'फेलिप',
#  'dell': 'डेल',
#  'maro': 'मारो',
#  'evergreen': 'एवरग्रीन',
#  'community': 'कम्युनिटी',
#  'keenan': 'कीनन',
#  'carch': 'चर्च',
#  'open': 'ओपन',
#  'door': 'दोओर',
#  'chau': 'चाउ',
#  'mahla': 'माहला',
#  'reliance': 'रिलायंस',
#  'naichura': 'नैच्युरा',
#  'prasam': 'प्राशम',
#  'archardas': 'ऑर्चर्ड्स',
#  'harway': 'हार्वे',
#  'avardas': 'अवार्ड्\u200dस',
#  'lopamudra': 'लोपमुद्रा',
#  'saeed': 'सईद',
#  'aajaad': 'आज़ाद',
#  'steav': 'स्टीव',
#  'wander': 'वॉन्डर',
#  'najar': 'नजर',
#  'union': 'यूनियन',
#  'pipe': 'पाइप',
#  'atttuniti': 'एट्टयूनिटी',
#  'cosmo': 'कोस्मो',
#  'oil': 'तेल',
#  'dwigt': 'ड्वाइट',
#  'humayrah': 'हुमयराह',
#  'rameez': 'रमीज़',
#  'satwik': 'सात्विक',
#  'dayton': 'डेटन',
#  'victim': 'शिकार',
#  'custer': 'कस्टर',
#  'offenpest': 'ऑफेनपेस्ट',
#  'caterpillar': 'केटरपिलर',
#  'shriram': 'श्रीराम',
#  'transfi': 'ट्रांसफ़ी',
#  'shiva': 'शिवा',
#  'gamma': 'गामा',
#  'four': 'फोर',
#  'continents': 'कॉनटिनेंट्\u200dस',
#  'figure': 'फिगर',
#  'skating': 'स्केटिंग',
#  'champions': 'चैंपियन्स',
#  'fuller': 'फुलर',
#  'murder': 'मर्डर',
#  'jacob': 'जेकब',
#  'aurum': 'ऑरम',
#  'bareerah': 'बरीरह',
#  'madhuri': 'माधुरी',
#  'institute': 'इंस्टीट्\u200dयूट',
#  'rocky': 'रॉकी',
#  'ananya': 'अनन्या',
#  'bar': 'बर',
#  'chale': 'चले',
#  'aao': 'आवो',
#  'gaverai': 'गेवरई',
#  'somkanta': 'सोमकांता',
#  'internet': 'इंटरनेट',
#  'initiative': 'इनीशिएटिव',
#  'japan': 'जापान',
#  ...}
